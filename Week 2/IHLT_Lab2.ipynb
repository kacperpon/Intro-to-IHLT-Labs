# %% [markdown]
# # IHLT Lab Exercise 2
# ## This file contains code to complete the exercise for the second lab session of IHLT
# Authors:
#
#
# *   Kacper Poniatowski (kacper.krzysztof.poniatowski@estudiantat.upc.edu)
# *   Pau Blanco (pablo.blanco@estudiantat.upc.edu)

# %% [markdown]
# # Provided code
# ## Paraphrases Template

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
dt = pd.read_csv('/content/drive/MyDrive/Notebooks/IHLT/Week2/test-gold/STS.input.SMTeuroparl.txt',sep='\t',header=None)

# %%
dt.head()
# Out:
#                                                    0  \
# 0  The leaders have now been given a new chance a...
# 1  Amendment No 7 proposes certain changes in the...
# 2  Let me remind you that our allies include ferv...
# 3        The vote will take place today at 5.30 p.m.
# 4  The fishermen are inactive, tired and disappoi...
#
#                                                    1
# 0  The leaders benefit aujourd' hui of a new luck...
# 1  Amendment No 7 is proposing certain changes in...
# 2  I would like to remind you that among our alli...
# 3                 The vote will take place at 5.30pm
# 4  The fishermen are inactive, tired and disappoi...

# %%
dt['gs'] = pd.read_csv('/content/drive/MyDrive/Notebooks/IHLT/Week2/test-gold/STS.gs.SMTeuroparl.txt',sep='\t',header=None)

# %%
dt.shape
# Out:
# (459, 3)

# %%
dt.head()
# Out:
#                                                    0  \
# 0  The leaders have now been given a new chance a...
# 1  Amendment No 7 proposes certain changes in the...
# 2  Let me remind you that our allies include ferv...
# 3        The vote will take place today at 5.30 p.m.
# 4  The fishermen are inactive, tired and disappoi...
#
#                                                    1    gs
# 0  The leaders benefit aujourd' hui of a new luck...  4.50
# 1  Amendment No 7 is proposing certain changes in...  5.00
# 2  I would like to remind you that among our alli...  4.25
# 3                 The vote will take place at 5.30pm  4.50
# 4  The fishermen are inactive, tired and disappoi...  5.00

# %% [markdown]
# ### TODO
# 1. Compute the Jaccard similarity between every paraphrase and add a column *jaccard* to *dt* variable.
# 2. Compute the pearson correlation as: <br>
# ```
# from scipy.stats import pearsonr
# pearsonr(dt['gs'], dt['jaccard'])[0]
# ```

# %% [markdown]
# # Solution

# %%
# Imports
import nltk
from nltk.metrics import jaccard_distance
from scipy.stats import pearsonr
from nltk.corpus import stopwords

nltk.download('stopwords')
nltk.download('punkt')

stopwords = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# Prepare new columns in the dataFrame
dt['jac'] = 0.0
dt['jac_low'] = 0.0
dt['jac_low_stop'] = 0.0
dt['jac_punct'] = 0.0

rowNums = dt.shape[0]

# Helper function to remove punctuation
def remove_punctuation(sentence):
    return [word for word in sentence if word.isalpha()]  # Only keep alphabetic words

for i in range(rowNums):
  # Get the sentences tokenized by punkt
  sentence0 = nltk.word_tokenize(dt.at[i, 0])
  sentence1 = nltk.word_tokenize(dt.at[i, 1])

  # 1. Original Jaccard Similarity
  dt.at[i, 'jac'] = 1- jaccard_distance(set(sentence0), set(sentence1))

  # 2. Lowercase Jaccard Similarity
  sentence0_low = [w.lower() for w in sentence0]
  sentence1_low = [w.lower() for w in sentence1]
  dt.at[i, 'jac_low'] = 1 - jaccard_distance(set(sentence0_low), set(sentence1_low))

  # 3. Lowercase and Remove Stopwords
  sentence0_low_stop = [w for w in sentence0_low if w not in stopwords]
  sentence1_low_stop = [w for w in sentence1_low if w not in stopwords]
  dt.at[i, 'jac_low_stop'] = 1 - jaccard_distance(set(sentence0_low_stop), set(sentence1_low_stop))

  # 4. Remove Punctuation (after lowercase)
  sentence0_no_punct = remove_punctuation(sentence0_low)
  sentence1_no_punct = remove_punctuation(sentence1_low)
  dt.at[i, 'jac_punct'] = 1 - jaccard_distance(set(sentence0_no_punct), set(sentence1_no_punct))

# Function to compute and store Pearson correlations
def compute_pearsonr(column_name, label):
    correlation = pearsonr(dt['gs'], dt[column_name])[0]
    print(f'Pearson correlation for {label} ({column_name}): {correlation:.6f}')
    return correlation

average_jac = dt['jac'].mean()
average_jac_low = dt['jac_low'].mean()
average_jac_low_stop = dt['jac_low_stop'].mean()
average_jac_punct = dt['jac_punct'].mean()

print('Jaccard distance mean for each preprocessing testcase: ')
print(f'Average Jaccard distance for raw sentences (lemmatized): {average_jac:.6f}')
print(f'Average Jaccard distance for sentences in lower case (lemmatized): {average_jac_low:.6f}')
print(f'Average Jaccard distance for sentences in lower case without stop words (lemmatized): {average_jac_low_stop:.6f}')
print(f'Average Jaccard distance for sentences in lower case without punctuation signs (lemmatized): {average_jac_punct:.6f}')

print('Pearson correlation between gold values and Jaccard distances (to 6 decimal places):')

# Store correlations in a dictionary for later use
correlations = {
    'Original': compute_pearsonr('jac', 'raw sentences'),
    'Lowercase': compute_pearsonr('jac_low', 'sentences in lower case'),
    'Lowercase without Stopwords': compute_pearsonr('jac_low_stop', 'sentences in lower case without stop words'),
    'Without Punctuation': compute_pearsonr('jac_punct', 'sentences in lower case without punctuation signs')
}

dt.head()
# Out:
# Jaccard distance mean for each preprocessing testcase:
# Average Jaccard distance for raw sentences (lemmatized): 0.500240
# Average Jaccard distance for sentences in lower case (lemmatized): 0.526905
# Average Jaccard distance for sentences in lower case without stop words (lemmatized): 0.531768
# Average Jaccard distance for sentences in lower case without punctuation signs (lemmatized): 0.518007
# Pearson correlation between gold values and Jaccard distances (to 6 decimal places):
# Pearson correlation for raw sentences (jac): 0.450498
# Pearson correlation for sentences in lower case (jac_low): 0.462495
# Pearson correlation for sentences in lower case without stop words (jac_low_stop): 0.445160
# Pearson correlation for sentences in lower case without punctuation signs (jac_punct): 0.458716
#                                                    0  \
# 0  The leaders have now been given a new chance a...
# 1  Amendment No 7 proposes certain changes in the...
# 2  Let me remind you that our allies include ferv...
# 3        The vote will take place today at 5.30 p.m.
# 4  The fishermen are inactive, tired and disappoi...
#
#                                                    1    gs       jac  \
# 0  The leaders benefit aujourd' hui of a new luck...  4.50  0.346154
# 1  Amendment No 7 is proposing certain changes in...  5.00  0.785714
# 2  I would like to remind you that among our alli...  4.25  0.391304
# 3                 The vote will take place at 5.30pm  4.50  0.545455
# 4  The fishermen are inactive, tired and disappoi...  5.00  1.000000
#
#     jac_low  jac_low_stop  jac_punct
# 0  0.346154      0.312500   0.347826
# 1  0.785714      0.777778   0.750000
# 2  0.391304      0.307692   0.380952
# 3  0.545455      0.375000   0.857143
# 4  1.000000      1.000000   1.000000

# %% [markdown]
# # Methodology
# We have been asked to correlate the gold standard results with the Jaccard distance. Initially, we tokenized the text directly with Punkt tokenizer, which showed that the correlation exists but has a poor result. Since the method behind the gold standard's creation wasn't explained, we have tried to preprocess the sentences to improve the results. These included converting all text to lowercase, removing stop words, and removing punctuation. In each subsequent test, we built on the previous test result that yielded the highest correlation.
#
# It should also be noted that gold standard values range from 0 to 5 while Jaccard distance ranges from 0 to 1. While the scales differ, it does not affect the correlation between the two variables therefore we decided against normalizing.
#
#
# # Conclusions
# In the 4 cases we have tested, we have been able to verify that there is indeed some correlation between the gold standard and the Jaccard distance. However, the results are modest, around 0.45, indicating that there is a certain degree of correlation but not a high degree of correlation.
#
# Lowercasing the text improved the results slightly, because it reduces the number of variations in the union and increases overlaps in similar phrases (e.g.: 'The leaders...' and 'Leaders...'). However, removing stop words worsened the results, and removing punctuation led to a minor improvement. We believe this inconsistency is created due to the gold standard potentially using more advanced NLP techniques such as analyzing sentence structure and synonym usage, while Jaccard distance simply measures the percentage of matching words.
#
# **Main Conclusion**
# The Jaccard distance, based on percentage of matching words, is too simplistic to reliably gauge sentence similarity.

# %% [markdown]
# # Annex
# Comparing sentences with different Jaccard distance when transforming to lower case

# %%
# Filter and print rows where the jac_low value differs from the jac value
# by more than 0.001.

# The aim is to highlight cases where preprocessing significantly impacts
# the similarity scores, which supports our argument that the Jaccard distance
# is too simplistic to capture sentence similarity accurately.

# By printing these cases, it offers concrete examples that shows why the Jaccard
# approach doesn't align well with the more complex gold standard.

dif_low = dt[(dt['jac_low'] - dt['jac']) > 0.001]
print(f"Number of rows where 'jac_low' differs from 'jac' by more than 0.001: {dif_low.shape[0]}")

dt.head()

for row in dif_low.itertuples():
    print(f"Sentence 1: {row[1]}")
    print(f"Sentence 2: {row[2]}")
    print(f"Original Jaccard: {row.jac:.4f}, Preprocessed Jaccard (Lowercased): {row.jac_low:.4f}")
    print("-" * 80)
# Out:
# Number of rows where 'jac_low' differs from 'jac' by more than 0.001: 117
# Sentence 1: Neither was there a qualified majority within this House to revert to Article 272.
# Sentence 2: There was not a majority voting in Parliament to go back to Article 272.
# Original Jaccard: 0.3333, Preprocessed Jaccard (Lowercased): 0.4000
# --------------------------------------------------------------------------------
# Sentence 1: The leaders have now been given a new chance and let us hope they seize it.
# Sentence 2: Leaders now have another chance to let them and therefore take.
# Original Jaccard: 0.2609, Preprocessed Jaccard (Lowercased): 0.3182
# --------------------------------------------------------------------------------
# Sentence 1: (Parliament adopted the legislative resolution)
# Sentence 2: (The Parliament adopts legislative resolution)
# Original Jaccard: 0.5556, Preprocessed Jaccard (Lowercased): 0.7500
# --------------------------------------------------------------------------------
# Sentence 1: As I already explained during second reading, there is a crisis underlying this directive amendment.
# Sentence 2: As I have already explained, at second reading, a crisis is at the root of this modification of Directive.
# Original Jaccard: 0.5000, Preprocessed Jaccard (Lowercased): 0.5652
# --------------------------------------------------------------------------------
# Sentence 1: We often pontificate here about being the representatives of the citizens of Europe.
# Sentence 2: Often we are proud of representing Europe's citizens.
# Original Jaccard: 0.2222, Preprocessed Jaccard (Lowercased): 0.3750
# --------------------------------------------------------------------------------
# Sentence 1: Then perhaps we could have avoided a catastrophe.
# Sentence 2: Perhaps we should have been able to prevent a disaster.
# Original Jaccard: 0.2500, Preprocessed Jaccard (Lowercased): 0.3333
# --------------------------------------------------------------------------------
# Sentence 1: We often pontificate here about being the representatives of the citizens of Europe.
# Sentence 2: We we take pride often here of representing the european citizens.
# Original Jaccard: 0.4118, Preprocessed Jaccard (Lowercased): 0.4375
# --------------------------------------------------------------------------------
# Sentence 1: Then perhaps we could have avoided a catastrophe.
# Sentence 2: Perhaps then we would have avoided a catastrophe.
# Original Jaccard: 0.5000, Preprocessed Jaccard (Lowercased): 0.8000
# --------------------------------------------------------------------------------
# Sentence 1: Neither was there a qualified majority within this House to revert to Article 272.
# Sentence 2: There was not either qualified majority within this Parliament to come back to the article 272.
# Original Jaccard: 0.3636, Preprocessed Jaccard (Lowercased): 0.5000
# --------------------------------------------------------------------------------
# Sentence 1: The leaders have now been given a new chance and let us hope they seize it.
# Sentence 2: The leaders benefit today of a new chance and thus let the matter.
# Original Jaccard: 0.3478, Preprocessed Jaccard (Lowercased): 0.3636
# --------------------------------------------------------------------------------
# Sentence 1: (Parliament adopted the legislative resolution)
# Sentence 2: (The Parliament adopts the legislative resolution)
# Original Jaccard: 0.6667, Preprocessed Jaccard (Lowercased): 0.7500
# --------------------------------------------------------------------------------
# Sentence 1: Neither was there a qualified majority within this House to revert to Article 272.
# Sentence 2: There was no more qualified majority voting in this Parliament to come back to Article 272.
# Original Jaccard: 0.3636, Preprocessed Jaccard (Lowercased): 0.4286
# --------------------------------------------------------------------------------
# Sentence 1: Neither was there a qualified majority within this House to revert to Article 272.
# Sentence 2: It does not was not no longer a majority voting in this Parliament to return to the article 272.
# Original Jaccard: 0.2800, Preprocessed Jaccard (Lowercased): 0.3333
# --------------------------------------------------------------------------------
# Sentence 1: The leaders have now been given a new chance and let us hope they seize it.
# Sentence 2: Given the leaders today a new chance and thus let the approach.
# Original Jaccard: 0.3182, Preprocessed Jaccard (Lowercased): 0.4500
# --------------------------------------------------------------------------------
# Sentence 1: Van Orden Report (A5-0241/2000)
# Sentence 2: Van Orden report (A5-0241 / 2000)
# Original Jaccard: 0.4000, Preprocessed Jaccard (Lowercased): 0.5556
# --------------------------------------------------------------------------------
# Sentence 1: Then perhaps we could have avoided a catastrophe.
# Sentence 2: We would perhaps then able prevent a disaster.
# Original Jaccard: 0.2000, Preprocessed Jaccard (Lowercased): 0.3846
# --------------------------------------------------------------------------------
# Sentence 1: Van Orden Report (A5-0241/2000)
# Sentence 2: Van Orden report In particular A5-0241 -- 2000)
# Original Jaccard: 0.2500, Preprocessed Jaccard (Lowercased): 0.3636
# --------------------------------------------------------------------------------
# Sentence 1: Van Orden Report (A5-0241/2000)
# Sentence 2: Mr Van Orden report (A5-0241 / 2000)
# Original Jaccard: 0.3636, Preprocessed Jaccard (Lowercased): 0.5000
# --------------------------------------------------------------------------------
# Sentence 1: Consumers will lose out, employees will lose out, Europe will lose competitive strength and growth.
# Sentence 2: The users are the losers, employees, and European competitiveness and growth régresseront.
# Original Jaccard: 0.2500, Preprocessed Jaccard (Lowercased): 0.2632
# --------------------------------------------------------------------------------
# Sentence 1: The fishermen are inactive, tired and disappointed.
# Sentence 2: Fishermen are inactive, tired and disappointment.
# Original Jaccard: 0.5455, Preprocessed Jaccard (Lowercased): 0.7000
# --------------------------------------------------------------------------------
# Sentence 1: The European Union has got to do something and do it quickly.
# Sentence 2: It is that the European Union is involved and that it do so quickly.
# Original Jaccard: 0.3889, Preprocessed Jaccard (Lowercased): 0.5000
# --------------------------------------------------------------------------------
# Sentence 1: Neither was there a qualified majority within this House to revert to Article 272.
# Sentence 2: There was no qualified majority in this Parliament to go back to Article 272.
# Original Jaccard: 0.4000, Preprocessed Jaccard (Lowercased): 0.4737
# --------------------------------------------------------------------------------
# Sentence 1: Amendment No 7 proposes certain changes in the references to paragraphs.
# Sentence 2: The amendment 7 proposes some changes in the references to the paragraphs.
# Original Jaccard: 0.6000, Preprocessed Jaccard (Lowercased): 0.7692
# --------------------------------------------------------------------------------
# Sentence 1: Consumers will lose out, employees will lose out, Europe will lose competitive strength and growth.
# Sentence 2: The users will be the losers, with the employees, and European competitiveness and growth will regress.
# Original Jaccard: 0.2857, Preprocessed Jaccard (Lowercased): 0.3000
# --------------------------------------------------------------------------------
# Sentence 1: Neither was there a qualified majority within this House to revert to Article 272.
# Sentence 2: There was no qualified majority in this Parliament to go back to Article 272.
# Original Jaccard: 0.4000, Preprocessed Jaccard (Lowercased): 0.4737
# --------------------------------------------------------------------------------
# Sentence 1: Then perhaps we could have avoided a catastrophe.
# Sentence 2: Perhaps we would then have to avoid a disaster.
# Original Jaccard: 0.2667, Preprocessed Jaccard (Lowercased): 0.4615
# --------------------------------------------------------------------------------
# Sentence 1: The European Union has got to do something and do it quickly.
# Sentence 2: It suits that the European Union implies itself and that she do it quickly.
# Original Jaccard: 0.3684, Preprocessed Jaccard (Lowercased): 0.4706
# --------------------------------------------------------------------------------
# Sentence 1: Selective aid, such as market support and a grass subsidy, are essential.
# Sentence 2: The occasional aid as the support of the market or the premium to grass is essential.
# Original Jaccard: 0.3182, Preprocessed Jaccard (Lowercased): 0.3333
# --------------------------------------------------------------------------------
# Sentence 1: The European Union has got to do something and do it quickly.
# Sentence 2: It is right that the European Union is involved, and for this to be done quickly.
# Original Jaccard: 0.2609, Preprocessed Jaccard (Lowercased): 0.3810
# --------------------------------------------------------------------------------
# Sentence 1: Van Orden Report (A5-0241/2000)
# Sentence 2: Van Orden report (A5-0241 / 2000)
# Original Jaccard: 0.4000, Preprocessed Jaccard (Lowercased): 0.5556
# --------------------------------------------------------------------------------
# Sentence 1: Unfortunately, others separate on the basis of accumulated hatred.
# Sentence 2: On others who are unfortunately in the reason of a vengeance gained.
# Original Jaccard: 0.2000, Preprocessed Jaccard (Lowercased): 0.3333
# --------------------------------------------------------------------------------
# Sentence 1: Neither was there a qualified majority within this House to revert to Article 272.
# Sentence 2: There was no qualified majority in this Parliament to go back to Article 272.
# Original Jaccard: 0.4000, Preprocessed Jaccard (Lowercased): 0.4737
# --------------------------------------------------------------------------------
# Sentence 1: Unfortunately, others separate on the basis of accumulated hatred.
# Sentence 2: Other separate unfortunately because of a grudge accumulated.
# Original Jaccard: 0.2500, Preprocessed Jaccard (Lowercased): 0.3333
# --------------------------------------------------------------------------------
# Sentence 1: Selective aid, such as market support and a grass subsidy, are essential.
# Sentence 2: The specific aid as the support of the market or the premium to the grass is necessary.
# Original Jaccard: 0.2609, Preprocessed Jaccard (Lowercased): 0.2727
# --------------------------------------------------------------------------------
# Sentence 1: The leaders have now been given a new chance and let us hope they seize it.
# Sentence 2: The leaders have now of a new chance and let -- therefore the take.
# Original Jaccard: 0.4545, Preprocessed Jaccard (Lowercased): 0.4762
# --------------------------------------------------------------------------------
# Sentence 1: Then perhaps we could have avoided a catastrophe.
# Sentence 2: We maybe then could have avoided a catastrophe.
# Original Jaccard: 0.5000, Preprocessed Jaccard (Lowercased): 0.8000
# --------------------------------------------------------------------------------
# Sentence 1: (Parliament adopted the legislative resolution)
# Sentence 2: (The Parliament adopts the legislative resolution)
# Original Jaccard: 0.6667, Preprocessed Jaccard (Lowercased): 0.7500
# --------------------------------------------------------------------------------
# Sentence 1: Selective aid, such as market support and a grass subsidy, are essential.
# Sentence 2: The specific aid as the support of the market or the premium on grass are essential.
# Original Jaccard: 0.3810, Preprocessed Jaccard (Lowercased): 0.4000
# --------------------------------------------------------------------------------
# Sentence 1: Van Orden Report (A5-0241/2000)
# Sentence 2: Van Orden report (5 / 2000)
# Original Jaccard: 0.4000, Preprocessed Jaccard (Lowercased): 0.5556
# --------------------------------------------------------------------------------
# Sentence 1: Van Orden Report (A5-0241/2000)
# Sentence 2: Van Orden report (5 / 2000)
# Original Jaccard: 0.4000, Preprocessed Jaccard (Lowercased): 0.5556
# --------------------------------------------------------------------------------
# Sentence 1: Maij-Weggen report (A5-0323/2000)
# Sentence 2: Report Maij-Weggen (A5-0323 / 2000)
# Original Jaccard: 0.3333, Preprocessed Jaccard (Lowercased): 0.5000
# --------------------------------------------------------------------------------
# Sentence 1: Consumers will lose out, employees will lose out, Europe will lose competitive strength and growth.
# Sentence 2: The consumers are the losers, with the employees, and the competitiveness and the growth European régresseront.
# Original Jaccard: 0.2381, Preprocessed Jaccard (Lowercased): 0.3158
# --------------------------------------------------------------------------------
# Sentence 1: Unfortunately, others separate on the basis of accumulated hatred.
# Sentence 2: Some separate themselves unfortunately in view of a grudge gained.
# Original Jaccard: 0.1579, Preprocessed Jaccard (Lowercased): 0.2222
# --------------------------------------------------------------------------------
# Sentence 1: Maij-Weggen report (A5-0323/2000)
# Sentence 2: Report Maij-Weggen In particular A5-0323 -- 2000)
# Original Jaccard: 0.1818, Preprocessed Jaccard (Lowercased): 0.3000
# --------------------------------------------------------------------------------
# Sentence 1: The European Union has got to do something and do it quickly.
# Sentence 2: It is appropriate that the European Union is involved and that it makes it quickly.
# Original Jaccard: 0.3158, Preprocessed Jaccard (Lowercased): 0.4118
# --------------------------------------------------------------------------------
# Sentence 1: Then perhaps we could have avoided a catastrophe.
# Sentence 2: We would perhaps then could prevent a disaster.
# Original Jaccard: 0.2857, Preprocessed Jaccard (Lowercased): 0.5000
# --------------------------------------------------------------------------------
# Sentence 1: Unfortunately, others separate on the basis of accumulated hatred.
# Sentence 2: D 'other separate themselves unfortunately because of an accumulated grudge.
# Original Jaccard: 0.2222, Preprocessed Jaccard (Lowercased): 0.2941
# --------------------------------------------------------------------------------
# Sentence 1: Selective aid, such as market support and a grass subsidy, are essential.
# Sentence 2: The specific aid as the support of the market or the premium to the grass are essential.
# Original Jaccard: 0.3810, Preprocessed Jaccard (Lowercased): 0.4000
# --------------------------------------------------------------------------------
# Sentence 1: Selective aid, such as market support and a grass subsidy, are essential.
# Sentence 2: The occasional aid as the market or the grass is essential.
# Original Jaccard: 0.3158, Preprocessed Jaccard (Lowercased): 0.3333
# --------------------------------------------------------------------------------
# Sentence 1: Then perhaps we could have avoided a catastrophe.
# Sentence 2: We might then have to avoid a disaster.
# Original Jaccard: 0.2000, Preprocessed Jaccard (Lowercased): 0.3846
# --------------------------------------------------------------------------------
# Sentence 1: The European Union has got to do something and do it quickly.
# Sentence 2: It is that the European Union is means and that it be done very soon.
# Original Jaccard: 0.2381, Preprocessed Jaccard (Lowercased): 0.3158
# --------------------------------------------------------------------------------
# Sentence 1: Van Orden Report (A5-0241/2000)
# Sentence 2: Van Orden report (A5-0241 / 2000)
# Original Jaccard: 0.4000, Preprocessed Jaccard (Lowercased): 0.5556
# --------------------------------------------------------------------------------
# Sentence 1: The European Union has got to do something and do it quickly.
# Sentence 2: It is that the European Union is involved and that it will soon.
# Original Jaccard: 0.2632, Preprocessed Jaccard (Lowercased): 0.3529
# --------------------------------------------------------------------------------
# Sentence 1: The European Union has got to do something and do it quickly.
# Sentence 2: It is right that the European Union is it entails, and do so quickly.
# Original Jaccard: 0.3500, Preprocessed Jaccard (Lowercased): 0.4444
# --------------------------------------------------------------------------------
# Sentence 1: The leaders have now been given a new chance and let us hope they seize it.
# Sentence 2: The leaders are here today to a new chance and let them therefore the take.
# Original Jaccard: 0.3200, Preprocessed Jaccard (Lowercased): 0.3333
# --------------------------------------------------------------------------------
# Sentence 1: Neither was there a qualified majority within this House to revert to Article 272.
# Sentence 2: There was no qualified majority in this Parliament to go back to Article 272.
# Original Jaccard: 0.4000, Preprocessed Jaccard (Lowercased): 0.4737
# --------------------------------------------------------------------------------
# Sentence 1: We often pontificate here about being the representatives of the citizens of Europe.
# Sentence 2: We we pride often here of representing the European citizens.
# Original Jaccard: 0.4375, Preprocessed Jaccard (Lowercased): 0.4667
# --------------------------------------------------------------------------------
# Sentence 1: Unfortunately, others separate on the basis of accumulated hatred.
# Sentence 2: Other separate unfortunately because of an accumulated resentment.
# Original Jaccard: 0.2500, Preprocessed Jaccard (Lowercased): 0.3333
# --------------------------------------------------------------------------------
# Sentence 1: I am one of those Members who attends sittings quite faithfully.
# Sentence 2: I form part of the members of Parliament who are rather honourably present.
# Original Jaccard: 0.1905, Preprocessed Jaccard (Lowercased): 0.2500
# --------------------------------------------------------------------------------
# Sentence 1: The European Union has got to do something and do it quickly.
# Sentence 2: It is appropriate that the European Union means and that it should do so quickly.
# Original Jaccard: 0.3500, Preprocessed Jaccard (Lowercased): 0.4444
# --------------------------------------------------------------------------------
# Sentence 1: Neither was there a qualified majority within this House to revert to Article 272.
# Sentence 2: There did not exist either of majority qualified within this Parliament to return in article 272.
# Original Jaccard: 0.2917, Preprocessed Jaccard (Lowercased): 0.4091
# --------------------------------------------------------------------------------
# Sentence 1: Maij-Weggen report (A5-0323/2000)
# Sentence 2: Report maij-weggen (A5-0323/2000)
# Original Jaccard: 0.4286, Preprocessed Jaccard (Lowercased): 1.0000
# --------------------------------------------------------------------------------
# Sentence 1: Unfortunately, others separate on the basis of accumulated hatred.
# Sentence 2: Others separate unfortunately because of an accumulated resentment.
# Original Jaccard: 0.2500, Preprocessed Jaccard (Lowercased): 0.4286
# --------------------------------------------------------------------------------
# Sentence 1: (Parliament adopted the legislative resolution)
# Sentence 2: , The Parliament adopted the legislative resolution --
# Original Jaccard: 0.5000, Preprocessed Jaccard (Lowercased): 0.5556
# --------------------------------------------------------------------------------
# Sentence 1: Selective aid, such as market support and a grass subsidy, are essential.
# Sentence 2: Support specific as the support of the market or the premium to the grass is necessary.
# Original Jaccard: 0.2174, Preprocessed Jaccard (Lowercased): 0.2273
# --------------------------------------------------------------------------------
# Sentence 1: Unfortunately, others separate on the basis of accumulated hatred.
# Sentence 2: Other divide unfortunately because of a grudge accumulated.
# Original Jaccard: 0.1765, Preprocessed Jaccard (Lowercased): 0.2500
# --------------------------------------------------------------------------------
# Sentence 1: Unfortunately, others separate on the basis of accumulated hatred.
# Sentence 2: Other divide unfortunately because of a grudge accumulated.
# Original Jaccard: 0.1765, Preprocessed Jaccard (Lowercased): 0.2500
# --------------------------------------------------------------------------------
# Sentence 1: Unfortunately, others separate on the basis of accumulated hatred.
# Sentence 2: Others are parting unfortunately because of a rancune gained.
# Original Jaccard: 0.1053, Preprocessed Jaccard (Lowercased): 0.2353
# --------------------------------------------------------------------------------
# Sentence 1: Unfortunately, others separate on the basis of accumulated hatred.
# Sentence 2: Other divide unfortunately due to a accumulated ill-will.
# Original Jaccard: 0.1111, Preprocessed Jaccard (Lowercased): 0.1765
# --------------------------------------------------------------------------------
# Sentence 1: Unfortunately, others separate on the basis of accumulated hatred.
# Sentence 2: Other diverge unfortunately owing to an accumulated vengeance.
# Original Jaccard: 0.1111, Preprocessed Jaccard (Lowercased): 0.1765
# --------------------------------------------------------------------------------
# Sentence 1: Unfortunately, others separate on the basis of accumulated hatred.
# Sentence 2: Other separate unfortunately because of resentment accumulated.
# Original Jaccard: 0.2667, Preprocessed Jaccard (Lowercased): 0.3571
# --------------------------------------------------------------------------------
# Sentence 1: Neither was there a qualified majority within this House to revert to Article 272.
# Sentence 2: There was not majority qualified within this Parliament to bring back to the article 272 either.
# Original Jaccard: 0.3636, Preprocessed Jaccard (Lowercased): 0.5000
# --------------------------------------------------------------------------------
# Sentence 1: Unfortunately, others separate on the basis of accumulated hatred.
# Sentence 2: Others unfortunately diverge in response to rancune gained.
# Original Jaccard: 0.0526, Preprocessed Jaccard (Lowercased): 0.1765
# --------------------------------------------------------------------------------
# Sentence 1: Then perhaps we could have avoided a catastrophe.
# Sentence 2: We could perhaps have been able to prevent a disaster.
# Original Jaccard: 0.3333, Preprocessed Jaccard (Lowercased): 0.4286
# --------------------------------------------------------------------------------
# Sentence 1: As I already explained during second reading, there is a crisis underlying this directive amendment.
# Sentence 2: As I have already explained to us at second reading, a crisis is at the root of this amendment to Directive.
# Original Jaccard: 0.5200, Preprocessed Jaccard (Lowercased): 0.5833
# --------------------------------------------------------------------------------
# Sentence 1: Neither was there a qualified majority within this House to revert to Article 272.
# Sentence 2: There was no qualified majority in this Parliament to go back to Article 272.
# Original Jaccard: 0.4000, Preprocessed Jaccard (Lowercased): 0.4737
# --------------------------------------------------------------------------------
# Sentence 1: Consumers will lose out, employees will lose out, Europe will lose competitive strength and growth.
# Sentence 2: The users will be the losers, with the employees, and European competitiveness and the growth will regress.
# Original Jaccard: 0.2857, Preprocessed Jaccard (Lowercased): 0.3000
# --------------------------------------------------------------------------------
# Sentence 1: Unfortunately, others separate on the basis of accumulated hatred.
# Sentence 2: Others separate themselves unfortunately because of an amassed grudge.
# Original Jaccard: 0.1667, Preprocessed Jaccard (Lowercased): 0.3125
# --------------------------------------------------------------------------------
# Sentence 1: The fishermen are inactive, tired and disappointed.
# Sentence 2: Fishermen are inactive, tired and disappointed.
# Original Jaccard: 0.7000, Preprocessed Jaccard (Lowercased): 0.8889
# --------------------------------------------------------------------------------
# Sentence 1: Then perhaps we could have avoided a catastrophe.
# Sentence 2: We might then have to avoid a disaster.
# Original Jaccard: 0.2000, Preprocessed Jaccard (Lowercased): 0.3846
# --------------------------------------------------------------------------------
# Sentence 1: The European Union has got to do something and do it quickly.
# Sentence 2: It is important that the European Union itself and to do it quickly.
# Original Jaccard: 0.4444, Preprocessed Jaccard (Lowercased): 0.5625
# --------------------------------------------------------------------------------
# Sentence 1: Amendment No 7 proposes certain changes in the references to paragraphs.
# Sentence 2: The amendment 7 proposes some modifications in the references to the paragraphs.
# Original Jaccard: 0.5000, Preprocessed Jaccard (Lowercased): 0.6429
# --------------------------------------------------------------------------------
# Sentence 1: The European Union has got to do something and do it quickly.
# Sentence 2: It is important that the European Union to be involved and to do it quickly.
# Original Jaccard: 0.4211, Preprocessed Jaccard (Lowercased): 0.5294
# --------------------------------------------------------------------------------
# Sentence 1: Unfortunately, others separate on the basis of accumulated hatred.
# Sentence 2: Other separate unfortunately because of a grudge accumulated.
# Original Jaccard: 0.2500, Preprocessed Jaccard (Lowercased): 0.3333
# --------------------------------------------------------------------------------
# Sentence 1: The European Union has got to do something and do it quickly.
# Sentence 2: It is appropriate that the European Union is and what it implies does it quickly.
# Original Jaccard: 0.3000, Preprocessed Jaccard (Lowercased): 0.3889
# --------------------------------------------------------------------------------
# Sentence 1: As I already explained during second reading, there is a crisis underlying this directive amendment.
# Sentence 2: As I have already explained at second reading, a crisis is at the root of this amendment to Directive.
# Original Jaccard: 0.5417, Preprocessed Jaccard (Lowercased): 0.6087
# --------------------------------------------------------------------------------
# Sentence 1: The European Union has got to do something and do it quickly.
# Sentence 2: It is necessary that the European Union gets involved and that it makes it fast.
# Original Jaccard: 0.2381, Preprocessed Jaccard (Lowercased): 0.3158
# --------------------------------------------------------------------------------
# Sentence 1: Then perhaps we could have avoided a catastrophe.
# Sentence 2: We would perhaps have been able to prevent a disaster.
# Original Jaccard: 0.2500, Preprocessed Jaccard (Lowercased): 0.3333
# --------------------------------------------------------------------------------
# Sentence 1: Neither was there a qualified majority within this House to revert to Article 272.
# Sentence 2: There was no qualified majority in this Parliament to go back to Article 272.
# Original Jaccard: 0.4000, Preprocessed Jaccard (Lowercased): 0.4737
# --------------------------------------------------------------------------------
# Sentence 1: It is our job to continue to support Latvia with the integration of the Russian population.
# Sentence 2: It is our duty of continue to support the Latvia on the issue of the integration of the russian people.
# Original Jaccard: 0.5500, Preprocessed Jaccard (Lowercased): 0.6316
# --------------------------------------------------------------------------------
# Sentence 1: Then perhaps we could have avoided a catastrophe.
# Sentence 2: We could perhaps then have avoided a catastrophe.
# Original Jaccard: 0.6364, Preprocessed Jaccard (Lowercased): 1.0000
# --------------------------------------------------------------------------------
# Sentence 1: Then perhaps we could have avoided a catastrophe.
# Sentence 2: We might then have to avoid a disaster.
# Original Jaccard: 0.2000, Preprocessed Jaccard (Lowercased): 0.3846
# --------------------------------------------------------------------------------
# Sentence 1: Neither was there a qualified majority within this House to revert to Article 272.
# Sentence 2: It did not exist either qualified majority in this Parliament to return to article 272.
# Original Jaccard: 0.2609, Preprocessed Jaccard (Lowercased): 0.3182
# --------------------------------------------------------------------------------
# Sentence 1: Then perhaps we could have avoided a catastrophe.
# Sentence 2: We would maybe then have been able to avoid a disaster.
# Original Jaccard: 0.1667, Preprocessed Jaccard (Lowercased): 0.3125
# --------------------------------------------------------------------------------
# Sentence 1: Van Orden Report (A5-0241/2000)
# Sentence 2: Van Orden report (A5-0241 / 2000)
# Original Jaccard: 0.4000, Preprocessed Jaccard (Lowercased): 0.5556
# --------------------------------------------------------------------------------
# Sentence 1: Consumers will lose out, employees will lose out, Europe will lose competitive strength and growth.
# Sentence 2: The users will be the losers, with the employees, and the competitiveness and growth regress.
# Original Jaccard: 0.3000, Preprocessed Jaccard (Lowercased): 0.3158
# --------------------------------------------------------------------------------
# Sentence 1: Neither was there a qualified majority within this House to revert to Article 272.
# Sentence 2: There was no qualified majority in this Parliament to go back to Article 272.
# Original Jaccard: 0.4000, Preprocessed Jaccard (Lowercased): 0.4737
# --------------------------------------------------------------------------------
# Sentence 1: Van Orden Report (A5-0241/2000)
# Sentence 2: Van Orden report (A5-0241 / 2000)
# Original Jaccard: 0.4000, Preprocessed Jaccard (Lowercased): 0.5556
# --------------------------------------------------------------------------------
# Sentence 1: The European Union has got to do something and do it quickly.
# Sentence 2: It suits that the European Union is implied and that it makesit rapidly.
# Original Jaccard: 0.2500, Preprocessed Jaccard (Lowercased): 0.3333
# --------------------------------------------------------------------------------
# Sentence 1: Selective aid, such as market support and a grass subsidy, are essential.
# Sentence 2: A specific aid as the support of the market or the premium on grass are essential.
# Original Jaccard: 0.3810, Preprocessed Jaccard (Lowercased): 0.4500
# --------------------------------------------------------------------------------
# Sentence 1: Consumers will lose out, employees will lose out, Europe will lose competitive strength and growth.
# Sentence 2: The users will be the losers, with the employees, and the European competitiveness and growth will recede.
# Original Jaccard: 0.2857, Preprocessed Jaccard (Lowercased): 0.3000
# --------------------------------------------------------------------------------
# Sentence 1: Van Orden Report (A5-0241/2000)
# Sentence 2: Van Orden report (A5-0241/2000)
# Original Jaccard: 0.7143, Preprocessed Jaccard (Lowercased): 1.0000
# --------------------------------------------------------------------------------
# Sentence 1: Amendment No 7 proposes certain changes in the references to paragraphs.
# Sentence 2: The amendment 7 proposes some changes in the references to the paragraphs.
# Original Jaccard: 0.6000, Preprocessed Jaccard (Lowercased): 0.7692
# --------------------------------------------------------------------------------
# Sentence 1: Unfortunately, others separate on the basis of accumulated hatred.
# Sentence 2: D ' others part unfortunately in reason d ' a collected resentment.
# Original Jaccard: 0.0952, Preprocessed Jaccard (Lowercased): 0.1579
# --------------------------------------------------------------------------------
# Sentence 1: I am one of those Members who attends sittings quite faithfully.
# Sentence 2: I am part of the members of parliament who are rather honorably present.
# Original Jaccard: 0.2500, Preprocessed Jaccard (Lowercased): 0.3158
# --------------------------------------------------------------------------------
# Sentence 1: Consumers will lose out, employees will lose out, Europe will lose competitive strength and growth.
# Sentence 2: The users will be the losers, with employees, and European competitiveness and growth will diminish.
# Original Jaccard: 0.2857, Preprocessed Jaccard (Lowercased): 0.3000
# --------------------------------------------------------------------------------
# Sentence 1: Consumers will lose out, employees will lose out, Europe will lose competitive strength and growth.
# Sentence 2: The users will be the losers, with employees, and European competitiveness and growth will diminish.
# Original Jaccard: 0.2857, Preprocessed Jaccard (Lowercased): 0.3000
# --------------------------------------------------------------------------------
# Sentence 1: Consumers will lose out, employees will lose out, Europe will lose competitive strength and growth.
# Sentence 2: The users will be the losers, with the employees, and the competitiveness and the European growths will decline.
# Original Jaccard: 0.2273, Preprocessed Jaccard (Lowercased): 0.2381
# --------------------------------------------------------------------------------
# Sentence 1: Consumers will lose out, employees will lose out, Europe will lose competitive strength and growth.
# Sentence 2: The users are the losers, with the employees, and the competitiveness and growth european régresseront.
# Original Jaccard: 0.2381, Preprocessed Jaccard (Lowercased): 0.2500
# --------------------------------------------------------------------------------
# Sentence 1: The European Union has got to do something and do it quickly.
# Sentence 2: It is appropriate that the European Union is implied and that it does it quickly.
# Original Jaccard: 0.3158, Preprocessed Jaccard (Lowercased): 0.4118
# --------------------------------------------------------------------------------
# Sentence 1: Then perhaps we could have avoided a catastrophe.
# Sentence 2: We would perhaps have been able to then avoid a disaster.
# Original Jaccard: 0.2353, Preprocessed Jaccard (Lowercased): 0.4000
# --------------------------------------------------------------------------------
# Sentence 1: We often pontificate here about being the representatives of the citizens of Europe.
# Sentence 2: Often we pride ourselves here to represent the people of Europe.
# Original Jaccard: 0.2632, Preprocessed Jaccard (Lowercased): 0.4118
# --------------------------------------------------------------------------------
# Sentence 1: The European Union has got to do something and do it quickly.
# Sentence 2: It is appropriate that the European Union means and that it should do so quickly.
# Original Jaccard: 0.3500, Preprocessed Jaccard (Lowercased): 0.4444
# --------------------------------------------------------------------------------
# Sentence 1: Unfortunately, others separate on the basis of accumulated hatred.
# Sentence 2: Other separate unfortunately a accumulated resentment.
# Original Jaccard: 0.2000, Preprocessed Jaccard (Lowercased): 0.2857
# --------------------------------------------------------------------------------
# Sentence 1: Then perhaps we could have avoided a catastrophe.
# Sentence 2: We might have been able to prevent a disaster.
# Original Jaccard: 0.1875, Preprocessed Jaccard (Lowercased): 0.2667
# --------------------------------------------------------------------------------
# Sentence 1: The vote will take place today at 5.30 p.m.
# Sentence 2: Vote will take place at 17 h 30.
# Original Jaccard: 0.3571, Preprocessed Jaccard (Lowercased): 0.4615
# --------------------------------------------------------------------------------
# Sentence 1: Neither was there a qualified majority within this House to revert to Article 272.
# Sentence 2: There was no qualified majority in this Parliament to go back to Article 272.
# Original Jaccard: 0.4000, Preprocessed Jaccard (Lowercased): 0.4737
# --------------------------------------------------------------------------------
