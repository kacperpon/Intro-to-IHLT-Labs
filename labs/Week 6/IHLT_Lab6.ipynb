# %% [markdown]
# # Solution

# %% [markdown]
# # IHLT Lab Exercise 6
# ## This file contains code to complete the exercise for the sixth lab session of IHLT
# Authors:
#
#
# *   Kacper Poniatowski (kacper.krzysztof.poniatowski@estudiantat.upc.edu)
# *   Pau Blanco (pablo.blanco@estudiantat.upc.edu)

# %% [markdown]
# ## Methodology
# In Lab 2 and Lab 3 we compared pairs of sentences using Jaccard distance and then compared the obtained results with the provided gold standard values using the Pearson correlation.
#
# In Lab 2 we used words while in Lab 3 the corresponding lemmas were used.
#
# In each lab, we computed the values using four different variations:
# * Raw Sentences
# * Sentences in lower case
# * Sentences in lower case removing stop words
# * Sentences in lower case removing punctuation (keeping only alphanumeric words)
#
# Following is the Pearson correlation we got for each variant:
#
# | Preprocessing Step | Using Words| Using Lemmas | Difference (%) |
# |-----------------|-----------------|-----------------|---|
# | Raw Sentences | 0.450498 | 0.476777  | 5.83% similarity increase using lemmas |
# | Lower Case | 0.462495  | 0.481508  | 4.11% similarity increase using lemmas |
# | Lower Case + No Stopwords | 0.445160  | 0.495948  | 11.41% similarity increase using lemmas |
# | Lower Case + No Punctuation | 0.458716  | 0.499157 | 8.82% similarity increase using lemmas |
#
# As seen in the table above, the best correlation using words was obtained when only applying lowercase. But when using lemmas, the best results were obtained when the punctuation was removed after lowercasing.
#
# In this exercise we are required to do a similar study but using synsets after disambiguating words instead of words or lemmas. Given our reference value is 0.499157 which was achieved using lemmas after applying lowercasing and removing punctuation, this steps aims to further refine word sense disambiguation. Similar to how lemmatisation led to improved scores compared to raw word tokens, we anticipate that incorporating word sense information will yield better results than the previously stated reference value.
#
# On a final note: when disambiguating with Lesk, we will get word senses for the 4 open-class categories only. This means a significant portion of words will be removed from the sentences. To be able to analyze the impact of this words, we will compute the Jaccard distances and correlation by using only the open-class categories and also including the lemmas of the words belonging to the rest of categories.
#
# It is worth mentioning that our intention was to disambiguate the words using Lesk and UKB. Unfortunately, we have not been able to complete the results of UKB due to the TextServer instability or quota limits. Before the conclusion section we have added the cells and code we intended to use.

# %% [markdown]
# ## Pre-reqs

# %%
from google.colab import drive
import sys

drive.mount('/content/drive', force_remount=True)
sys.path.insert(0, '/content/drive/MyDrive/Notebooks/IHLT/Week6')
import pandas as pd

dt = pd.read_csv('/content/drive/MyDrive/Notebooks/IHLT/Week6/test-gold/STS.input.SMTeuroparl.txt',sep='\t',header=None)
dt['gs'] = pd.read_csv('/content/drive/MyDrive/Notebooks/IHLT/Week6/test-gold/STS.gs.SMTeuroparl.txt',sep='\t',header=None)

dt.head()
# Out:
# Mounted at /content/drive
#                                                    0  \
# 0  The leaders have now been given a new chance a...
# 1  Amendment No 7 proposes certain changes in the...
# 2  Let me remind you that our allies include ferv...
# 3        The vote will take place today at 5.30 p.m.
# 4  The fishermen are inactive, tired and disappoi...
#
#                                                    1    gs
# 0  The leaders benefit aujourd' hui of a new luck...  4.50
# 1  Amendment No 7 is proposing certain changes in...  5.00
# 2  I would like to remind you that among our alli...  4.25
# 3                 The vote will take place at 5.30pm  4.50
# 4  The fishermen are inactive, tired and disappoi...  5.00

# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('punkt_tab')
nltk.download("punkt")

from nltk.metrics import jaccard_distance
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from scipy.stats import pearsonr

# from textserver import TextServer
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## Exercise

# %% [markdown]
# ### Common Functions

# %%
# Function to compute and store Pearson correlations
def compute_pearsonr(column_name, label):
    correlation = pearsonr(dt['gs'], dt[column_name])[0]
    print(f'Pearson correlation for {label} ({column_name}): {correlation:.6f}')
    return correlation

def preProcessTokens(tokens):
  # Lowerize and keep only alphanumeric words (exclude numbers and punctuation)
  return [w.lower() for w in tokens if w.isalpha()]

# %% [markdown]
# ### Lesk in NLTK

# %%
# Functions and pre-work
lemmatizer = WordNetLemmatizer()

dt_jac = dt
dt_jac['jac_lesk_remove_no_sense'] = 0.0
dt_jac['jac_lesk_lemmatise_no_sense'] = 0.0

def disambiguate_sentence(sentence, remove_word, verbose = False):
    tokens = preProcessTokens(word_tokenize(sentence))
    senses = []
    if verbose:
      print("Tokens:", tokens)
    for word in tokens:
      sense = nltk.wsd.lesk(tokens, word)  # Apply Lesk for Word Sense Disambiguation
      if sense:
        if verbose:
          print(word, '->', sense.name(), ':', sense.definition())
        senses.append(sense.name())  # Get the synset name (e.g., 'bank.n.01')
      else:
        if remove_word:
          continue  # If no synset is found, remove word in this case
        else:
          lemma = lemmatizer.lemmatize(word)
          senses.append(lemma)  # Append the lemma to the list
    return senses

def calculate_lesk_jaccard(remove_word, verbose = False):
  similarities = []

  row_nums = dt.shape[0]

  for i in range(row_nums):
    sentence0 = dt.at[i, 0]
    sentence1 = dt.at[i, 1]

    if verbose:
      print("#################")
      print("     Sentence 1:", sentence0)
    senses0 = disambiguate_sentence(sentence0, remove_word, verbose)
    if verbose:
      print("     Sentence 2:", sentence1)
    senses1 = disambiguate_sentence(sentence1, remove_word, verbose)

    if remove_word:
      dt_jac.at[i, 'jac_lesk_remove_no_sense'] = 1 - jaccard_distance(set(senses0), set(senses1))
    else:
      dt_jac.at[i, 'jac_lesk_lemmatise_no_sense'] = 1 - jaccard_distance(set(senses0), set(senses1))

# %% [markdown]
# #### Lesk + Removing Words without Senses

# %%
# Compute similarities by considering senses and Jaccard coefficient (REMOVE WORDS WITHOUT SENSES)
calculate_lesk_jaccard(remove_word = True)

average_jac_lesk_remove_no_sense = dt_jac['jac_lesk_remove_no_sense'].mean()

print(f"Average Jaccard similarity for sentences using Lesk (removing words with no senses): {average_jac_lesk_remove_no_sense:.6f}")
# Out:
# Average Jaccard similarity for sentences using Lesk (removing words with no senses): 0.423957

# %% [markdown]
# #### Lesk + Using lemmas / forms

# %%
# Compute similarities by considering senses and Jaccard coefficient (USE EITHER LEMMAS OR WORD FORMS FOR WORDS WITHOUT SENSES)
calculate_lesk_jaccard(remove_word = False)

average_jac_lesk_lemmatise_no_sense = dt_jac['jac_lesk_lemmatise_no_sense'].mean()

print(f"Average Jaccard similarity for sentences using Lesk (using lemmas with no senses): {average_jac_lesk_lemmatise_no_sense:.6f}")
# Out:
# Average Jaccard similarity for sentences using Lesk (using lemmas with no senses): 0.457442

# %% [markdown]
# #### Pearson Correlation with Lesk

# %%
correlations = {
    'Lesk (sense only)': compute_pearsonr('jac_lesk_remove_no_sense', 'lesk with removal of words with no sense'),
    'Lesk (lemmas for sensesless words)': compute_pearsonr('jac_lesk_lemmatise_no_sense', 'lesk and using lemmas for senseless words'),
}
# Out:
# Pearson correlation for lesk with removal of words with no sense (jac_lesk_remove_no_sense): 0.413353
# Pearson correlation for lesk and using lemmas for senseless words (jac_lesk_lemmatise_no_sense): 0.412781

# %% [markdown]
# ### UKB in TextServer (Work in Progress due to TextServer limitations)

# %%
ts = TextServer("kacperp12", "textserver123-", "senses") # This works, surprisingly

dt_jac['jac_ukb_remove_no_senses'] = 0.0
dt_jac['jac_ukb_lemmatise_no_senses'] = 0.0

cache = {}

def calculate_ukb_jaccard_dist(remove_word):
  similarities = []
  row_nums = dt.shape[0]

  for i in range(5):
    sentence0 = dt.at[i, 0]
    sentence1 = dt.at[i, 1]

    # Cache results because TextServer is slow as Christmas
    if sentence0 in cache:
        senses0 = cache[sentence0]
    else:
        senses0 = ts.senses(sentence0)
        cache[sentence0] = senses0

    if sentence1 in cache:
        senses1 = cache[sentence1]
    else:
        senses1 = ts.senses(sentence1)
        cache[sentence1] = senses1

    # If remove_word = true, remove entries where no senses were found ('N/A')
    if remove_word:
        # Filter out words with no senses (senses0 and senses1 are lists of words with their senses)
        filtered_senses0 = [word[4] for word in senses0 if word[4] != 'N/A']
        filtered_senses1 = [word[4] for word in senses1 if word[4] != 'N/A']

        # Calculate Jaccard similarity for filtered senses
        dt_jac.at[i, 'jac_ukb_remove_no_sense'] = 1 - jaccard_distance(set(filtered_senses0), set(filtered_senses1))

    # If remove_word = false, fallback to the lemma form where no sense is found
    else:
        # If the sense is 'N/A', use the lemma (word[1])
        processed_senses0 = [word[4] if word[4] != 'N/A' else word[1] for word in senses0]
        processed_senses1 = [word[4] if word[4] != 'N/A' else word[1] for word in senses1]

        # Calculate Jaccard similarity using the processed senses (sense or lemma)
        dt_jac.at[i, 'jac_ukb_lemmatise_no_sense'] = 1 - jaccard_distance(set(processed_senses0), set(processed_senses1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0e4ee2f287e0> in <cell line: 1>()
# ----> 1 ts = TextServer("kacperp12", "textserver123-", "senses") # This works, surprisingly
#       2
#       3 dt_jac['jac_ukb_remove_no_senses'] = 0.0
#       4 dt_jac['jac_ukb_lemmatise_no_senses'] = 0.0
#       5
#
# NameError: name 'TextServer' is not defined

# %% [markdown]
# #### UKB + Removing Words without Senses

# %%
# Compute similarities by considering senses and Jaccard coefficient (REMOVE WORDS WITHOUT SENSES)

#calculate_ukb_jaccard_dist(remove_word = True)


row_nums = dt_jac.shape[0]

sentence0 = dt.at[0, 0]

ts.senses(sentence0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-bd7cfa0f444a> in <cell line: 6>()
#       4
#       5
# ----> 6 row_nums = dt_jac.shape[0]
#       7
#       8 sentence0 = dt.at[0, 0]
#
# NameError: name 'dt_jac' is not defined

# %% [markdown]
# #### UKB + Using lemmas / forms

# %%
# Compute similarities by considering senses and Jaccard coefficient (USE EITHER LEMMAS OR WORD FORMS FOR WORDS WITHOUT SENSES)

# %% [markdown]
# ## Conclusions

# %% [markdown]
# The following table summarizes the results obtained so far for lowercase sentences and without punctuations:
#
# | Comparison method | Mean Jaccard Distance | Pearson Correlation|
# |-|-|-|
# | Words (Lab 2) | 0.518007 | 0.458716  |
# | Lemmas (Lab 3) | 0.530221  | 0.499157  |
# | Senses | 0.423957 | **0.413353**  |
# | Senses + Lemmas | 0.457442  | **0.412781** |
#
# The first evident conclusion is that our hypothesis stating that the use of senses should perform better than using lemmas (or words) was incorrect. The mean Jaccard similarities are lower than those obtained by words and lemmas.
# The decrease in correlation is noteworthy, especially since it performed worse than even the most basic word comparison methods.
#
# From these results, we can conclude that Lesk performs poorly at disambiguating words. We can visualise this poor performance by further analysis: the output of Lesk. In the next cell we can see each sentence and the synsets assigned.
#
# It is not difficult to find poor disambiguation. For instance:
#
# ------
# Sentence 1: Let me remind you that our allies include fervent supporters of this tax.
#
# tax -> **tax.v.02** : set or determine the amount of (a payment such as a fine)
#
# Sentence 2: I want to remind you that of our allies, it is of major of tax.
# major -> major.v.01 : have as one's principal field of study
#
# tax -> **tax.v.03** : use to the limit
#
# ------
# In the above sentences, tax should have the same meaning, but Lesk is assigning different senses. Words or lemmas would count the words as positive match.
#
# Another example:
#
# ------
# Sentence 1: The leaders have now been given a new chance and let us hope they seize it.
#
# have -> **have.v.07** : have a personal or business relationship with someone
#
# Sentence 2: The leaders now have another chance to let them and therefore seize it.
#
# have -> **take.v.35** : have sex with; archaic use
#
# ------
#
# Once again, the same problem is evident. The word 'have' (no comments about the hilarious meaning assigned in one of the sentences...).
#
# In this same pair of sentences we can see how an incorrect meaning is assigned to "it". Besides that, it has no negative impact as the same wrong meaning is assigned in both sentences:
#
# it -> information_technology.n.01 : the branch of engineering that deals with the use of computers and telecommunications to retrieve and store and transmit information.
#
# We can therefore conclude that the results have worsened due to Lesk's poor performance for the assigned task. Perhaps with other disambiguation algorithms (we regret not being able to complete the tests with UKB), the results could be improved.

# %% [markdown]
# ### Detailed view on Lesk disambiguation

# %%
# Let's give some light
calculate_lesk_jaccard(remove_word = True, verbose = True)
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# honourably -> honorably.r.02 : with honor
# #################
#      Sentence 1: Mr President, the Cashman report can be summarised in four words: citizens' power over bureaucracy.
# Tokens: ['mr', 'president', 'the', 'cashman', 'report', 'can', 'be', 'summarised', 'in', 'four', 'words', 'citizens', 'power', 'over', 'bureaucracy']
# mr -> mister.n.01 : a form of address for a man
# president -> president_of_the_united_states.n.02 : the office of the United States head of state
# report -> report.v.05 : be responsible for reporting the details of, as in journalism
# can -> can.n.02 : the quantity contained in a can
# be -> exist.v.01 : have an existence, be extant
# summarised -> summarize.v.02 : be a summary of
# in -> indium.n.01 : a rare soft silvery metallic element; occurs in small quantities in sphalerite
# four -> four.n.01 : the cardinal number that is the sum of three and one
# words -> words.n.01 : the words that are spoken
# citizens -> citizen.n.01 : a native or naturalized member of a state or other political community
# power -> power.v.01 : supply the force or power for the functioning of
# over -> all_over.r.01 : over the entire area
# bureaucracy -> bureaucracy.n.03 : any organization in which action is obstructed by insistence on unnecessary procedures and red tape
#      Sentence 2: Mister the President, the report Cashman can summarize itself in some words: the strength of the citizens on the bureaucracy.
# Tokens: ['mister', 'the', 'president', 'the', 'report', 'cashman', 'can', 'summarize', 'itself', 'in', 'some', 'words', 'the', 'strength', 'of', 'the', 'citizens', 'on', 'the', 'bureaucracy']
# mister -> mister.n.01 : a form of address for a man
# president -> president_of_the_united_states.n.02 : the office of the United States head of state
# report -> report.v.01 : to give an account or representation of in words
# can -> can.n.02 : the quantity contained in a can
# summarize -> summarize.v.02 : be a summary of
# in -> in.r.01 : to or toward the inside of
# some -> some.s.03 : relatively many but unspecified in number
# words -> son.n.02 : the divine word of God; the second person in the Trinity (incarnate in Jesus)
# strength -> military_capability.n.01 : capability in terms of personnel and materiel that affect the capacity to fight a war
# citizens -> citizen.n.01 : a native or naturalized member of a state or other political community
# on -> on.r.03 : in a state required for something to function or be effective
# bureaucracy -> bureaucracy.n.03 : any organization in which action is obstructed by insistence on unnecessary procedures and red tape
# #################
#      Sentence 1: The European Union has got to do something and do it quickly.
# Tokens: ['the', 'european', 'union', 'has', 'got', 'to', 'do', 'something', 'and', 'do', 'it', 'quickly']
# european -> european.a.01 : of or relating to or characteristic of Europe or the people of Europe
# union -> union.s.01 : being of or having to do with the northern United States and those loyal to the Union during the American Civil War
# has -> hour_angle.n.02 : (astronomy) the angular distance of a celestial point measured westward along the celestial equator from the zenith crossing; the right ascension for an observer at a particular location and time of day
# got -> make.v.02 : give certain properties to something
# do -> practice.v.01 : carry out or practice; as of jobs and professions
# do -> practice.v.01 : carry out or practice; as of jobs and professions
# it -> information_technology.n.01 : the branch of engineering that deals with the use of computers and telecommunications to retrieve and store and transmit information
# quickly -> quickly.r.01 : with rapid movements
#      Sentence 2: It is that the European Union is involved and that it will soon.
# Tokens: ['it', 'is', 'that', 'the', 'european', 'union', 'is', 'involved', 'and', 'that', 'it', 'will', 'soon']
# it -> information_technology.n.01 : the branch of engineering that deals with the use of computers and telecommunications to retrieve and store and transmit information
# is -> be.v.01 : have the quality of being; (copula, used with an adjective or a predicate noun)
# european -> european.a.01 : of or relating to or characteristic of Europe or the people of Europe
# union -> union.s.01 : being of or having to do with the northern United States and those loyal to the Union during the American Civil War
# is -> be.v.01 : have the quality of being; (copula, used with an adjective or a predicate noun)
# involved -> involved.s.03 : emotionally involved
# it -> information_technology.n.01 : the branch of engineering that deals with the use of computers and telecommunications to retrieve and store and transmit information
# will -> volition.n.01 : the capability of conscious choice and decision and intention; - George Meredith
# soon -> soon.r.01 : in the near future
# #################
#      Sentence 1: I am one of those Members who attends sittings quite faithfully.
# Tokens: ['i', 'am', 'one', 'of', 'those', 'members', 'who', 'attends', 'sittings', 'quite', 'faithfully']
# i -> one.s.01 : used of a single unit or thing; not two or more
# am -> embody.v.02 : represent, as of a character on stage
# one -> one.s.03 : of the same kind or quality
# members -> member.n.01 : one of the persons who compose a social group (especially individuals who have joined and participate in a group organization)
# who -> world_health_organization.n.01 : a United Nations agency to coordinate international health activities and to help governments improve health services
# attends -> attend.v.02 : take charge of or deal with
# sittings -> sitting.n.04 : a session as of a legislature or court
# quite -> quite.r.03 : of an unusually noticeable or exceptional or remarkable kind (not used with a negative)
# faithfully -> faithfully.r.01 : in a faithful manner
#      Sentence 2: I am one of the Members who are quite honourably here.
# Tokens: ['i', 'am', 'one', 'of', 'the', 'members', 'who', 'are', 'quite', 'honourably', 'here']
# i -> i.n.03 : the 9th letter of the Roman alphabet
# am -> be.v.01 : have the quality of being; (copula, used with an adjective or a predicate noun)
# one -> one.s.03 : of the same kind or quality
# members -> member.n.01 : one of the persons who compose a social group (especially individuals who have joined and participate in a group organization)
# who -> world_health_organization.n.01 : a United Nations agency to coordinate international health activities and to help governments improve health services
# are -> be.v.01 : have the quality of being; (copula, used with an adjective or a predicate noun)
# quite -> quite.r.03 : of an unusually noticeable or exceptional or remarkable kind (not used with a negative)
# honourably -> honorably.r.02 : with honor
# here -> hera.n.01 : queen of the Olympian gods in ancient Greek mythology; sister and wife of Zeus remembered for her jealously of the many mortal women Zeus fell in love with; identified with Roman Juno
# #################
#      Sentence 1: The fishermen are inactive, tired and disappointed.
# Tokens: ['the', 'fishermen', 'are', 'inactive', 'tired', 'and', 'disappointed']
# fishermen -> fisherman.n.01 : someone whose occupation is catching fish
# are -> be.v.01 : have the quality of being; (copula, used with an adjective or a predicate noun)
# inactive -> dormant.a.02 : (of e.g. volcanos) not erupting and not extinct
# tired -> tire.v.02 : exhaust or get tired through overuse or great strain or stress
# disappointed -> disappoint.v.01 : fail to meet the hopes or expectations of
#      Sentence 2: The fishermen are inactive, tired and disappointed.
# Tokens: ['the', 'fishermen', 'are', 'inactive', 'tired', 'and', 'disappointed']
# fishermen -> fisherman.n.01 : someone whose occupation is catching fish
# are -> be.v.01 : have the quality of being; (copula, used with an adjective or a predicate noun)
# inactive -> dormant.a.02 : (of e.g. volcanos) not erupting and not extinct
# tired -> tire.v.02 : exhaust or get tired through overuse or great strain or stress
# disappointed -> disappoint.v.01 : fail to meet the hopes or expectations of
# #################
#      Sentence 1: The European Union has got to do something and do it quickly.
# Tokens: ['the', 'european', 'union', 'has', 'got', 'to', 'do', 'something', 'and', 'do', 'it', 'quickly']
# european -> european.a.01 : of or relating to or characteristic of Europe or the people of Europe
# union -> union.s.01 : being of or having to do with the northern United States and those loyal to the Union during the American Civil War
# has -> hour_angle.n.02 : (astronomy) the angular distance of a celestial point measured westward along the celestial equator from the zenith crossing; the right ascension for an observer at a particular location and time of day
# got -> make.v.02 : give certain properties to something
# do -> practice.v.01 : carry out or practice; as of jobs and professions
# do -> practice.v.01 : carry out or practice; as of jobs and professions
# it -> information_technology.n.01 : the branch of engineering that deals with the use of computers and telecommunications to retrieve and store and transmit information
# quickly -> quickly.r.01 : with rapid movements
#      Sentence 2: It is right that the European Union is it entails, and do so quickly.
# Tokens: ['it', 'is', 'right', 'that', 'the', 'european', 'union', 'is', 'it', 'entails', 'and', 'do', 'so', 'quickly']
# it -> information_technology.n.01 : the branch of engineering that deals with the use of computers and telecommunications to retrieve and store and transmit information
# is -> be.v.01 : have the quality of being; (copula, used with an adjective or a predicate noun)
# right -> right.n.05 : the hand that is on the right side of the body
# european -> european.a.01 : of or relating to or characteristic of Europe or the people of Europe
# union -> union.s.01 : being of or having to do with the northern United States and those loyal to the Union during the American Civil War
# is -> be.v.01 : have the quality of being; (copula, used with an adjective or a predicate noun)
# it -> information_technology.n.01 : the branch of engineering that deals with the use of computers and telecommunications to retrieve and store and transmit information
# entails -> fee-tail.v.01 : limit the inheritance of property to a specific class of heirs
# do -> practice.v.01 : carry out or practice; as of jobs and professions
# so -> thus.r.02 : in the way indicated; ; ; (`thusly' is a nonstandard variant)
# quickly -> quickly.r.01 : with rapid movements
# #################
#      Sentence 1: Mr President, I rise in defence of the workers in the industry.
# Tokens: ['mr', 'president', 'i', 'rise', 'in', 'defence', 'of', 'the', 'workers', 'in', 'the', 'industry']
# mr -> mister.n.01 : a form of address for a man
# president -> president_of_the_united_states.n.02 : the office of the United States head of state
# i -> iodine.n.01 : a nonmetallic element belonging to the halogens; used especially in medicine and photography and in dyes; occurs naturally only in combination in small quantities (as in sea water or rocks)
# rise -> rise.n.02 : the act of changing location in an upward direction
# in -> in.r.01 : to or toward the inside of
# defence -> refutation.n.01 : the speech act of answering an attack on your assertions
# workers -> worker.n.03 : sterile member of a colony of social insects that forages for food and cares for the larvae
# in -> in.r.01 : to or toward the inside of
# industry -> industry.n.01 : the people or companies engaged in a particular kind of commercial enterprise
#      Sentence 2: Mr President, I want to stand up for workers of this area.
# Tokens: ['mr', 'president', 'i', 'want', 'to', 'stand', 'up', 'for', 'workers', 'of', 'this', 'area']
# mr -> mister.n.01 : a form of address for a man
# president -> president_of_the_united_states.n.02 : the office of the United States head of state
# i -> one.s.01 : used of a single unit or thing; not two or more
# want -> want.v.03 : hunt or look for; want for a particular reason
# stand -> stand.n.10 : tiered seats consisting of a structure (often made of wood) where people can sit to watch an event (game or parade)
# up -> up.s.08 : used up
# workers -> worker.n.03 : sterile member of a colony of social insects that forages for food and cares for the larvae
# area -> sphere.n.01 : a particular environment or walk of life
# #################
#      Sentence 1: There must be a balance as a whole.
# Tokens: ['there', 'must', 'be', 'a', 'balance', 'as', 'a', 'whole']
# there -> there.n.01 : a location other than here; that place
# must -> must.n.01 : a necessary or essential thing
# be -> embody.v.02 : represent, as of a character on stage
# a -> deoxyadenosine_monophosphate.n.01 : one of the four nucleotides used in building DNA; all four nucleotides have a common phosphate group and a sugar (ribose)
# balance -> proportion.n.05 : harmonious arrangement or relation of parts or elements within a whole (as in a design); - John Ruskin
# as -> arsenic.n.02 : a very poisonous metallic element that has three allotropic forms; arsenic and arsenic compounds are used as herbicides and insecticides and various alloys; found in arsenopyrite and orpiment and realgar
# a -> deoxyadenosine_monophosphate.n.01 : one of the four nucleotides used in building DNA; all four nucleotides have a common phosphate group and a sugar (ribose)
# whole -> solid.s.15 : acting together as a single undiversified whole
#      Sentence 2: The unit must be in balance.
# Tokens: ['the', 'unit', 'must', 'be', 'in', 'balance']
# unit -> unit.n.05 : a single undivided natural thing occurring in the composition of something else
# must -> mustiness.n.01 : the quality of smelling or tasting old or stale or mouldy
# be -> exist.v.01 : have an existence, be extant
# in -> indium.n.01 : a rare soft silvery metallic element; occurs in small quantities in sphalerite
# balance -> libra.n.03 : the seventh sign of the zodiac; the sun is in this sign from about September 23 to October 22
# #################
#      Sentence 1: Unanimous decisions, and hence an inherent incapacity to act, remain largely the norm in the Council.
# Tokens: ['unanimous', 'decisions', 'and', 'hence', 'an', 'inherent', 'incapacity', 'to', 'act', 'remain', 'largely', 'the', 'norm', 'in', 'the', 'council']
# unanimous -> consentaneous.s.01 : in complete agreement
# decisions -> decision.n.01 : the act of making up your mind about something
# hence -> therefore.r.01 : (used to introduce a logical conclusion) from that fact or reason or as a result
# an -> associate_in_nursing.n.01 : an associate degree in nursing
# inherent -> implicit_in.s.01 : in the nature of something though not readily apparent
# incapacity -> incapacity.n.02 : lack of physical or natural qualifications
# act -> work.v.03 : have an effect or outcome; often the one desired or expected
# remain -> stay.v.01 : stay the same; remain in a certain state
# largely -> largely.r.01 : in large part; mainly or chiefly
# norm -> average.n.01 : a statistic describing the location of a distribution
# in -> in.r.01 : to or toward the inside of
# council -> council.n.02 : (Christianity) an assembly of theologians and bishops and other representatives of different churches or dioceses that is convened to regulate matters of discipline or doctrine
#      Sentence 2: We keep l ' unanimity in Council and therefore a latent inability to act.
# Tokens: ['we', 'keep', 'l', 'unanimity', 'in', 'council', 'and', 'therefore', 'a', 'latent', 'inability', 'to', 'act']
# keep -> retain.v.02 : allow to remain in a place or position or maintain a property or feature
# l -> liter.n.01 : a metric unit of capacity, formerly defined as the volume of one kilogram of pure water under standard conditions; now equal to 1,000 cubic centimeters (or approximately 1.75 pints)
# unanimity -> unanimity.n.01 : everyone being of one mind
# in -> indium.n.01 : a rare soft silvery metallic element; occurs in small quantities in sphalerite
# council -> council.n.02 : (Christianity) an assembly of theologians and bishops and other representatives of different churches or dioceses that is convened to regulate matters of discipline or doctrine
# therefore -> therefore.r.01 : (used to introduce a logical conclusion) from that fact or reason or as a result
# a -> deoxyadenosine_monophosphate.n.01 : one of the four nucleotides used in building DNA; all four nucleotides have a common phosphate group and a sugar (ribose)
# latent -> latent.s.02 : (pathology) not presently active
# inability -> inability.n.02 : lacking the power to perform
# act -> act.v.02 : behave in a certain manner; show a certain behavior; conduct or comport oneself
# #################
#      Sentence 1: The standards are scarcely comparable, let alone transferable.
# Tokens: ['the', 'standards', 'are', 'scarcely', 'comparable', 'let', 'alone', 'transferable']
# standards -> standard.n.04 : the value behind the money in a monetary system
# are -> be.v.01 : have the quality of being; (copula, used with an adjective or a predicate noun)
# scarcely -> hardly.r.02 : almost not
# comparable -> comparable.s.02 : conforming in every respect
# let -> let.n.02 : a serve that strikes the net before falling into the receiver's court; the ball must be served again
# alone -> entirely.r.02 : without any others being included or involved
# transferable -> assignable.s.01 : legally transferable to the ownership of another
#      Sentence 2: Norms are barely comparable and even less alienable.
# Tokens: ['norms', 'are', 'barely', 'comparable', 'and', 'even', 'less', 'alienable']
# norms -> norm.n.01 : a standard or model or pattern regarded as typical
# are -> exist.v.01 : have an existence, be extant
# barely -> scantily.r.01 : in a sparse or scanty way
# comparable -> comparable.s.02 : conforming in every respect
# even -> even.a.03 : being level or straight or regular and without variation as e.g. in shape or texture; or being in the same plane or at the same height as something else (i.e. even with)
# less -> less.r.01 : used to form the comparative of some adjectives and adverbs
# alienable -> alienable.a.01 : transferable to another owner
# #################
#      Sentence 1: The leaders have now been given a new chance and let us hope they seize it.
# Tokens: ['the', 'leaders', 'have', 'now', 'been', 'given', 'a', 'new', 'chance', 'and', 'let', 'us', 'hope', 'they', 'seize', 'it']
# leaders -> leadership.n.02 : the body of people who lead a group
# have -> have.v.07 : have a personal or business relationship with someone
# now -> now.r.01 : in the historical present; at this point in the narration of a series of past events
# been -> be.v.01 : have the quality of being; (copula, used with an adjective or a predicate noun)
# given -> yield.v.01 : be the cause or source of
# a -> deoxyadenosine_monophosphate.n.01 : one of the four nucleotides used in building DNA; all four nucleotides have a common phosphate group and a sugar (ribose)
# new -> newfangled.s.01 : (of a new kind or fashion) gratuitously new
# chance -> probability.n.01 : a measure of how likely it is that some event will occur; a number expressing the ratio of favorable cases to the whole number of cases possible
# let -> let.v.01 : make it possible through a specific action or lack of action for something to happen
# us -> uranium.n.01 : a heavy toxic silvery-white radioactive metallic element; occurs in many isotopes; used for nuclear fuels and nuclear weapons
# hope -> promise.n.02 : grounds for feeling hopeful about the future
# seize -> seize.v.06 : hook by a pull on the line
# it -> information_technology.n.01 : the branch of engineering that deals with the use of computers and telecommunications to retrieve and store and transmit information
#      Sentence 2: The leaders are here today to a new chance and let them therefore the take.
# Tokens: ['the', 'leaders', 'are', 'here', 'today', 'to', 'a', 'new', 'chance', 'and', 'let', 'them', 'therefore', 'the', 'take']
# leaders -> leadership.n.02 : the body of people who lead a group
# are -> be.v.01 : have the quality of being; (copula, used with an adjective or a predicate noun)
# here -> here.r.03 : to this place (especially toward the speaker)
# today -> today.n.02 : the day that includes the present moment (as opposed to yesterday or tomorrow)
# a -> deoxyadenosine_monophosphate.n.01 : one of the four nucleotides used in building DNA; all four nucleotides have a common phosphate group and a sugar (ribose)
# new -> newfangled.s.01 : (of a new kind or fashion) gratuitously new
# chance -> probability.n.01 : a measure of how likely it is that some event will occur; a number expressing the ratio of favorable cases to the whole number of cases possible
# let -> let.v.01 : make it possible through a specific action or lack of action for something to happen
# therefore -> therefore.r.01 : (used to introduce a logical conclusion) from that fact or reason or as a result
# take -> take.v.34 : to get into a position of having, e.g., safety, comfort
# #################
#      Sentence 1: Mr President, I rise in defence of the workers in the industry.
# Tokens: ['mr', 'president', 'i', 'rise', 'in', 'defence', 'of', 'the', 'workers', 'in', 'the', 'industry']
# mr -> mister.n.01 : a form of address for a man
# president -> president_of_the_united_states.n.02 : the office of the United States head of state
# i -> iodine.n.01 : a nonmetallic element belonging to the halogens; used especially in medicine and photography and in dyes; occurs naturally only in combination in small quantities (as in sea water or rocks)
# rise -> rise.n.02 : the act of changing location in an upward direction
# in -> in.r.01 : to or toward the inside of
# defence -> refutation.n.01 : the speech act of answering an attack on your assertions
# workers -> worker.n.03 : sterile member of a colony of social insects that forages for food and cares for the larvae
# in -> in.r.01 : to or toward the inside of
# industry -> industry.n.01 : the people or companies engaged in a particular kind of commercial enterprise
#      Sentence 2: Mr. President, I make a point of taking the defense of the workers of this sector.
# Tokens: ['president', 'i', 'make', 'a', 'point', 'of', 'taking', 'the', 'defense', 'of', 'the', 'workers', 'of', 'this', 'sector']
# president -> president.n.05 : the head administrative officer of a college or university
# i -> one.n.01 : the smallest whole number or a numeral representing this number
# make -> shuffle.n.01 : the act of mixing cards haphazardly
# a -> deoxyadenosine_monophosphate.n.01 : one of the four nucleotides used in building DNA; all four nucleotides have a common phosphate group and a sugar (ribose)
# point -> point.n.22 : the property of a shape that tapers to a sharp tip
# taking -> film.v.01 : make a film or photograph of something
# defense -> defense.n.11 : a defendant's answer or plea denying the truth of the charges against him
# workers -> worker.n.03 : sterile member of a colony of social insects that forages for food and cares for the larvae
# sector -> sector.n.04 : the minimum track length that can be assigned to store information; unless otherwise specified a sector of data consists of 512 bytes
# #################
#      Sentence 1: Tunisia
# Tokens: ['tunisia']
# tunisia -> tunisia.n.01 : a republic in northwestern Africa on the Mediterranean coast; achieved independence from France in 1956
#      Sentence 2: Tunisia
# Tokens: ['tunisia']
# tunisia -> tunisia.n.01 : a republic in northwestern Africa on the Mediterranean coast; achieved independence from France in 1956
# #################
#      Sentence 1: Neither was there a qualified majority within this House to revert to Article 272.
# Tokens: ['neither', 'was', 'there', 'a', 'qualified', 'majority', 'within', 'this', 'house', 'to', 'revert', 'to', 'article']
# neither -> neither.s.01 : not either; not one or the other
# was -> washington.n.02 : a state in northwestern United States on the Pacific
# there -> there.r.03 : to or toward that place; away from the speaker
# a -> angstrom.n.01 : a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation
# qualified -> certified.s.03 : holding appropriate documentation and officially on record as qualified to perform a specified function or practice a specified skill
# majority -> majority.n.03 : the age at which persons are considered competent to manage their own affairs
# within -> inside.r.02 : on the inside
# house -> house.n.09 : the management of a gambling house or casino
# revert -> revert.v.01 : go back to a previous state
# article -> article.v.01 : bind by a contract; especially for a training period
#      Sentence 2: There was no qualified majority in this Parliament to go back to Article 272.
# Tokens: ['there', 'was', 'no', 'qualified', 'majority', 'in', 'this', 'parliament', 'to', 'go', 'back', 'to', 'article']
# there -> there.r.03 : to or toward that place; away from the speaker
# was -> be.v.12 : to remain unmolested, undisturbed, or uninterrupted -- used only in infinitive form
# no -> no.r.03 : used to express refusal or denial or disagreement etc or especially to emphasize a negative statement
# qualified -> certified.s.03 : holding appropriate documentation and officially on record as qualified to perform a specified function or practice a specified skill
# majority -> majority.n.01 : the property resulting from being or relating to the greater in number of two parts; the main part
# in -> indium.n.01 : a rare soft silvery metallic element; occurs in small quantities in sphalerite
# parliament -> fantan.n.02 : a card game in which you play your sevens and other cards in sequence in the same suit as the sevens; you win if you are the first to use all your cards
# go -> rifle.v.02 : go through in search of something; search through someone's belongings in an unauthorized way
# back -> back.v.06 : be in back of
# article -> article.v.01 : bind by a contract; especially for a training period
# #################
#      Sentence 1: Unanimous decisions, and hence an inherent incapacity to act, remain largely the norm in the Council.
# Tokens: ['unanimous', 'decisions', 'and', 'hence', 'an', 'inherent', 'incapacity', 'to', 'act', 'remain', 'largely', 'the', 'norm', 'in', 'the', 'council']
# unanimous -> consentaneous.s.01 : in complete agreement
# decisions -> decision.n.01 : the act of making up your mind about something
# hence -> therefore.r.01 : (used to introduce a logical conclusion) from that fact or reason or as a result
# an -> associate_in_nursing.n.01 : an associate degree in nursing
# inherent -> implicit_in.s.01 : in the nature of something though not readily apparent
# incapacity -> incapacity.n.02 : lack of physical or natural qualifications
# act -> work.v.03 : have an effect or outcome; often the one desired or expected
# remain -> stay.v.01 : stay the same; remain in a certain state
# largely -> largely.r.01 : in large part; mainly or chiefly
# norm -> average.n.01 : a statistic describing the location of a distribution
# in -> in.r.01 : to or toward the inside of
# council -> council.n.02 : (Christianity) an assembly of theologians and bishops and other representatives of different churches or dioceses that is convened to regulate matters of discipline or doctrine
#      Sentence 2: We keep unanimity in the Council and thus a latent failure to act.
# Tokens: ['we', 'keep', 'unanimity', 'in', 'the', 'council', 'and', 'thus', 'a', 'latent', 'failure', 'to', 'act']
# keep -> retain.v.02 : allow to remain in a place or position or maintain a property or feature
# unanimity -> unanimity.n.01 : everyone being of one mind
# in -> indium.n.01 : a rare soft silvery metallic element; occurs in small quantities in sphalerite
# council -> council.n.02 : (Christianity) an assembly of theologians and bishops and other representatives of different churches or dioceses that is convened to regulate matters of discipline or doctrine
# thus -> thus.r.02 : in the way indicated; ; ; (`thusly' is a nonstandard variant)
# a -> deoxyadenosine_monophosphate.n.01 : one of the four nucleotides used in building DNA; all four nucleotides have a common phosphate group and a sugar (ribose)
# latent -> latent.s.02 : (pathology) not presently active
# failure -> failure.n.07 : loss of ability to function normally
# act -> act.v.02 : behave in a certain manner; show a certain behavior; conduct or comport oneself
# #################
#      Sentence 1: Maij-Weggen report (A5-0323/2000)
# Tokens: ['report']
# report -> report.n.02 : the act of informing by verbal report
#      Sentence 2: The report Maij-Weggen, A5-0323/2000 --
# Tokens: ['the', 'report']
# report -> report.n.02 : the act of informing by verbal report
# #################
#      Sentence 1: Mr President, the Cashman report can be summarised in four words: citizens' power over bureaucracy.
# Tokens: ['mr', 'president', 'the', 'cashman', 'report', 'can', 'be', 'summarised', 'in', 'four', 'words', 'citizens', 'power', 'over', 'bureaucracy']
# mr -> mister.n.01 : a form of address for a man
# president -> president_of_the_united_states.n.02 : the office of the United States head of state
# report -> report.v.05 : be responsible for reporting the details of, as in journalism
# can -> can.n.02 : the quantity contained in a can
# be -> exist.v.01 : have an existence, be extant
# summarised -> summarize.v.02 : be a summary of
# in -> indium.n.01 : a rare soft silvery metallic element; occurs in small quantities in sphalerite
# four -> four.n.01 : the cardinal number that is the sum of three and one
# words -> words.n.01 : the words that are spoken
# citizens -> citizen.n.01 : a native or naturalized member of a state or other political community
# power -> power.v.01 : supply the force or power for the functioning of
# over -> all_over.r.01 : over the entire area
# bureaucracy -> bureaucracy.n.03 : any organization in which action is obstructed by insistence on unnecessary procedures and red tape
#      Sentence 2: Mr President, the Cashman report can be summed up in a few words: the power of citizens on bureaucracy.
# Tokens: ['mr', 'president', 'the', 'cashman', 'report', 'can', 'be', 'summed', 'up', 'in', 'a', 'few', 'words', 'the', 'power', 'of', 'citizens', 'on', 'bureaucracy']
# mr -> mister.n.01 : a form of address for a man
# president -> president.n.05 : the head administrative officer of a college or university
# report -> report.v.05 : be responsible for reporting the details of, as in journalism
# can -> can.n.02 : the quantity contained in a can
# be -> embody.v.02 : represent, as of a character on stage
# summed -> summarize.v.02 : be a summary of
# up -> up.a.01 : being or moving higher in position or greater in some value; being above a former position or level
# in -> indium.n.01 : a rare soft silvery metallic element; occurs in small quantities in sphalerite
# a -> deoxyadenosine_monophosphate.n.01 : one of the four nucleotides used in building DNA; all four nucleotides have a common phosphate group and a sugar (ribose)
# few -> few.a.01 : a quantifier that can be used with count nouns and is often preceded by `a'; a small but indefinite number
# words -> actor's_line.n.01 : words making up the dialogue of a play
# power -> power.v.01 : supply the force or power for the functioning of
# citizens -> citizen.n.01 : a native or naturalized member of a state or other political community
# on -> on.r.03 : in a state required for something to function or be effective
# bureaucracy -> bureaucracy.n.03 : any organization in which action is obstructed by insistence on unnecessary procedures and red tape
# #################
#      Sentence 1: We often pontificate here about being the representatives of the citizens of Europe.
# Tokens: ['we', 'often', 'pontificate', 'here', 'about', 'being', 'the', 'representatives', 'of', 'the', 'citizens', 'of', 'europe']
# often -> often.r.03 : in many cases or instances
# pontificate -> papacy.n.01 : the government of the Roman Catholic Church
# here -> here.s.01 : being here now
# about -> about.s.01 : on the move
# being -> being.n.01 : the state or fact of existing
# representatives -> congressman.n.01 : a member of the United States House of Representatives
# citizens -> citizen.n.01 : a native or naturalized member of a state or other political community
# europe -> europe.n.03 : the nations of the European continent collectively
#      Sentence 2: We we pride often here of representing the European citizens.
# Tokens: ['we', 'we', 'pride', 'often', 'here', 'of', 'representing', 'the', 'european', 'citizens']
# pride -> pride.n.05 : unreasonable and inordinate self-esteem (personified as one of the deadly sins)
# often -> often.r.03 : in many cases or instances
# here -> hera.n.01 : queen of the Olympian gods in ancient Greek mythology; sister and wife of Zeus remembered for her jealously of the many mortal women Zeus fell in love with; identified with Roman Juno
# representing -> represent.v.04 : be a delegate or spokesperson for; represent somebody's interest or be a proxy or substitute for, as of politicians and office holders representing their constituents, or of a tenant representing other tenants in a housing dispute
# european -> european.a.01 : of or relating to or characteristic of Europe or the people of Europe
# citizens -> citizen.n.01 : a native or naturalized member of a state or other political community
# #################
#      Sentence 1: Maij-Weggen report (A5-0323/2000)
# Tokens: ['report']
# report -> report.n.02 : the act of informing by verbal report
#      Sentence 2: Maij-Weggen report (A5-0323/2000)
# Tokens: ['report']
# report -> report.n.02 : the act of informing by verbal report
# #################
#      Sentence 1: That provision could open the door wide to arbitrariness.
# Tokens: ['that', 'provision', 'could', 'open', 'the', 'door', 'wide', 'to', 'arbitrariness']
# provision -> provision.n.02 : the activity of supplying or providing something
# open -> open.v.01 : cause to open or to become open
# door -> doorway.n.01 : the entrance (the space in a wall) through which you enter or leave a room or building; the space that a door can close
# wide -> wide.r.02 : to the fullest extent possible
# arbitrariness -> flightiness.n.01 : the trait of acting unpredictably and more from whim or caprice than from reason or judgment
#      Sentence 2: This point of Procedure opens the door to the arbitrary.
# Tokens: ['this', 'point', 'of', 'procedure', 'opens', 'the', 'door', 'to', 'the', 'arbitrary']
# point -> point.n.22 : the property of a shape that tapers to a sharp tip
# procedure -> procedure.n.01 : a particular course of action intended to achieve a result
# opens -> open.v.11 : display the contents of a file or start an application as on a computer
# door -> doorway.n.01 : the entrance (the space in a wall) through which you enter or leave a room or building; the space that a door can close
# arbitrary -> arbitrary.a.01 : based on or subject to individual discretion or preference or sometimes impulse or caprice
# #################
#      Sentence 1: Unfortunately, others separate on the basis of accumulated hatred.
# Tokens: ['unfortunately', 'others', 'separate', 'on', 'the', 'basis', 'of', 'accumulated', 'hatred']
# unfortunately -> unfortunately.r.01 : by bad luck
# separate -> discriminate.v.02 : treat differently on the basis of sex or race
# on -> on.r.03 : in a state required for something to function or be effective
# basis -> basis.n.03 : the most important or necessary part of something
# accumulated -> accrued.s.01 : periodically accumulated over time
# hatred -> hate.n.01 : the emotion of intense dislike; a feeling of dislike so strong that it demands action
#      Sentence 2: Other separate unfortunately because of an accumulated resentment.
# Tokens: ['other', 'separate', 'unfortunately', 'because', 'of', 'an', 'accumulated', 'resentment']
# other -> other.s.04 : very unusual; different in character or quality from the normal or expected; - Lance Morrow
# separate -> separate.v.08 : discontinue an association or relation; go different ways
# unfortunately -> unfortunately.r.01 : by bad luck
# an -> associate_in_nursing.n.01 : an associate degree in nursing
# accumulated -> accrued.s.01 : periodically accumulated over time
# resentment -> resentment.n.01 : a feeling of deep and bitter anger and ill-will
# #################
#      Sentence 1: Let me remind you that our allies include fervent supporters of this tax.
# Tokens: ['let', 'me', 'remind', 'you', 'that', 'our', 'allies', 'include', 'fervent', 'supporters', 'of', 'this', 'tax']
# let -> let.v.01 : make it possible through a specific action or lack of action for something to happen
# me -> maine.n.01 : a state in New England
# remind -> remind.v.01 : put in the mind of someone
# allies -> allies.n.02 : in World War I the alliance of Great Britain and France and Russia and all the other nations that became allied with them in opposing the Central Powers
# include -> include.v.03 : add as part of something else; put in as part of a set, group, or category
# fervent -> fervent.s.02 : extremely hot; - Nathaniel Hawthorne; - Frances Trollope
# supporters -> assistant.n.01 : a person who contributes to the fulfillment of a need or furtherance of an effort or purpose
# tax -> tax.v.02 : set or determine the amount of (a payment such as a fine)
#      Sentence 2: I want to remind you that of our allies, it is of major of tax.
# Tokens: ['i', 'want', 'to', 'remind', 'you', 'that', 'of', 'our', 'allies', 'it', 'is', 'of', 'major', 'of', 'tax']
# i -> one.s.01 : used of a single unit or thing; not two or more
# want -> lack.n.01 : the state of needing something that is absent or unavailable
# remind -> remind.v.01 : put in the mind of someone
# allies -> allies.n.03 : an alliance of nations joining together to fight a common enemy
# it -> information_technology.n.01 : the branch of engineering that deals with the use of computers and telecommunications to retrieve and store and transmit information
# is -> equal.v.01 : be identical or equivalent to
# major -> major.v.01 : have as one's principal field of study
# tax -> tax.v.03 : use to the limit
# #################
#      Sentence 1: Maij-Weggen report (A5-0323/2000)
# Tokens: ['report']
# report -> report.n.02 : the act of informing by verbal report
#      Sentence 2: Maij-Weggen report (A5-0323 / 2000)
# Tokens: ['report']
# report -> report.n.02 : the act of informing by verbal report
# #################
#      Sentence 1: The leaders have now been given a new chance and let us hope they seize it.
# Tokens: ['the', 'leaders', 'have', 'now', 'been', 'given', 'a', 'new', 'chance', 'and', 'let', 'us', 'hope', 'they', 'seize', 'it']
# leaders -> leadership.n.02 : the body of people who lead a group
# have -> have.v.07 : have a personal or business relationship with someone
# now -> now.r.01 : in the historical present; at this point in the narration of a series of past events
# been -> be.v.01 : have the quality of being; (copula, used with an adjective or a predicate noun)
# given -> yield.v.01 : be the cause or source of
# a -> deoxyadenosine_monophosphate.n.01 : one of the four nucleotides used in building DNA; all four nucleotides have a common phosphate group and a sugar (ribose)
# new -> newfangled.s.01 : (of a new kind or fashion) gratuitously new
# chance -> probability.n.01 : a measure of how likely it is that some event will occur; a number expressing the ratio of favorable cases to the whole number of cases possible
# let -> let.v.01 : make it possible through a specific action or lack of action for something to happen
# us -> uranium.n.01 : a heavy toxic silvery-white radioactive metallic element; occurs in many isotopes; used for nuclear fuels and nuclear weapons
# hope -> promise.n.02 : grounds for feeling hopeful about the future
# seize -> seize.v.06 : hook by a pull on the line
# it -> information_technology.n.01 : the branch of engineering that deals with the use of computers and telecommunications to retrieve and store and transmit information
#      Sentence 2: The leaders now have another chance to let them and therefore seize it.
# Tokens: ['the', 'leaders', 'now', 'have', 'another', 'chance', 'to', 'let', 'them', 'and', 'therefore', 'seize', 'it']
# leaders -> leadership.n.02 : the body of people who lead a group
# now -> now.r.07 : in the immediate past
# have -> take.v.35 : have sex with; archaic use
# another -> another.s.01 : any of various alternatives; some other
# chance -> probability.n.01 : a measure of how likely it is that some event will occur; a number expressing the ratio of favorable cases to the whole number of cases possible
# let -> let.v.01 : make it possible through a specific action or lack of action for something to happen
# therefore -> therefore.r.01 : (used to introduce a logical conclusion) from that fact or reason or as a result
# seize -> assume.v.06 : seize and take control without authority and possibly with force; take as one's right or possession
# it -> information_technology.n.01 : the branch of engineering that deals with the use of computers and telecommunications to retrieve and store and transmit information
# #################
#      Sentence 1: I am one of those Members who attends sittings quite faithfully.
# Tokens: ['i', 'am', 'one', 'of', 'those', 'members', 'who', 'attends', 'sittings', 'quite', 'faithfully']
# i -> one.s.01 : used of a single unit or thing; not two or more
# am -> embody.v.02 : represent, as of a character on stage
# one -> one.s.03 : of the same kind or quality
# members -> member.n.01 : one of the persons who compose a social group (especially individuals who have joined and participate in a group organization)
# who -> world_health_organization.n.01 : a United Nations agency to coordinate international health activities and to help governments improve health services
# attends -> attend.v.02 : take charge of or deal with
# sittings -> sitting.n.04 : a session as of a legislature or court
# quite -> quite.r.03 : of an unusually noticeable or exceptional or remarkable kind (not used with a negative)
# faithfully -> faithfully.r.01 : in a faithful manner
#      Sentence 2: I form part of the members of Parliament who are rather honourably present.
# Tokens: ['i', 'form', 'part', 'of', 'the', 'members', 'of', 'parliament', 'who', 'are', 'rather', 'honourably', 'present']
# i -> i.n.03 : the 9th letter of the Roman alphabet
# form -> class.n.02 : a body of students who are taught together
# part -> region.n.01 : the extended spatial location of something
# members -> member.n.01 : one of the persons who compose a social group (especially individuals who have joined and participate in a group organization)
# parliament -> fantan.n.02 : a card game in which you play your sevens and other cards in sequence in the same suit as the sevens; you win if you are the first to use all your cards
# who -> world_health_organization.n.01 : a United Nations agency to coordinate international health activities and to help governments improve health services
# are -> be.v.01 : have the quality of being; (copula, used with an adjective or a predicate noun)
# rather -> rather.r.01 : on the contrary
# honourably -> honorably.r.02 : with honor
# present -> present.v.12 : formally present a debutante, a representative of a country, etc.
# #################
#      Sentence 1: We often pontificate here about being the representatives of the citizens of Europe.
# Tokens: ['we', 'often', 'pontificate', 'here', 'about', 'being', 'the', 'representatives', 'of', 'the', 'citizens', 'of', 'europe']
# often -> often.r.03 : in many cases or instances
# pontificate -> papacy.n.01 : the government of the Roman Catholic Church
# here -> here.s.01 : being here now
# about -> about.s.01 : on the move
# being -> being.n.01 : the state or fact of existing
# representatives -> congressman.n.01 : a member of the United States House of Representatives
# citizens -> citizen.n.01 : a native or naturalized member of a state or other political community
# europe -> europe.n.03 : the nations of the European continent collectively
#      Sentence 2: We often enorgueillissons ourselves here to represent the European citizens.
# Tokens: ['we', 'often', 'enorgueillissons', 'ourselves', 'here', 'to', 'represent', 'the', 'european', 'citizens']
# often -> often.r.03 : in many cases or instances
# here -> here.r.03 : to this place (especially toward the speaker)
# represent -> represent.v.01 : take the place of or be parallel or equivalent to
# european -> european.a.01 : of or relating to or characteristic of Europe or the people of Europe
# citizens -> citizen.n.01 : a native or naturalized member of a state or other political community
# #################
#      Sentence 1: Mr President, the Cashman report can be summarised in four words: citizens' power over bureaucracy.
# Tokens: ['mr', 'president', 'the', 'cashman', 'report', 'can', 'be', 'summarised', 'in', 'four', 'words', 'citizens', 'power', 'over', 'bureaucracy']
# mr -> mister.n.01 : a form of address for a man
# president -> president_of_the_united_states.n.02 : the office of the United States head of state
# report -> report.v.05 : be responsible for reporting the details of, as in journalism
# can -> can.n.02 : the quantity contained in a can
# be -> exist.v.01 : have an existence, be extant
# summarised -> summarize.v.02 : be a summary of
# in -> indium.n.01 : a rare soft silvery metallic element; occurs in small quantities in sphalerite
# four -> four.n.01 : the cardinal number that is the sum of three and one
# words -> words.n.01 : the words that are spoken
# citizens -> citizen.n.01 : a native or naturalized member of a state or other political community
# power -> power.v.01 : supply the force or power for the functioning of
# over -> all_over.r.01 : over the entire area
# bureaucracy -> bureaucracy.n.03 : any organization in which action is obstructed by insistence on unnecessary procedures and red tape
#      Sentence 2: Mr President, the Cashman report can be summarised as follows: the citizens on bureaucracy.
# Tokens: ['mr', 'president', 'the', 'cashman', 'report', 'can', 'be', 'summarised', 'as', 'follows', 'the', 'citizens', 'on', 'bureaucracy']
# mr -> mister.n.01 : a form of address for a man
# president -> president_of_the_united_states.n.02 : the office of the United States head of state
# report -> report.v.05 : be responsible for reporting the details of, as in journalism
# can -> can.n.02 : the quantity contained in a can
# be -> embody.v.02 : represent, as of a character on stage
# summarised -> summarize.v.02 : be a summary of
# as -> american_samoa.n.01 : a United States territory on the eastern part of the island of Samoa
# follows -> succeed.v.02 : be the successor (of)
# citizens -> citizen.n.01 : a native or naturalized member of a state or other political community
# on -> on.r.03 : in a state required for something to function or be effective
# bureaucracy -> bureaucracy.n.03 : any organization in which action is obstructed by insistence on unnecessary procedures and red tape
# #################
#      Sentence 1: Amendment No 7 proposes certain changes in the references to paragraphs.
# Tokens: ['amendment', 'no', 'proposes', 'certain', 'changes', 'in', 'the', 'references', 'to', 'paragraphs']
# amendment -> amendment.n.02 : a statement that is added to or revises or improves a proposal or document (a bill or constitution etc.)
# no -> no.r.01 : referring to the degree to which a certain quality is present
# proposes -> propose.v.05 : ask (someone) to marry you
# certain -> certain.a.04 : certain to occur; destined or inevitable; ; ; - Benjamin Franklin
# changes -> transfer.v.06 : change from one vehicle or transportation line to another
# in -> in.r.01 : to or toward the inside of
# references -> reference.n.10 : the relation between a word or phrase and the object or idea it refers to
# paragraphs -> paragraph.n.01 : one of several distinct subdivisions of a text intended to separate ideas; the beginning is usually marked by a new indented line
#      Sentence 2: Amendment 7 changes in references to paragraphs.
# Tokens: ['amendment', 'changes', 'in', 'references', 'to', 'paragraphs']
# amendment -> amendment.n.02 : a statement that is added to or revises or improves a proposal or document (a bill or constitution etc.)
# changes -> transfer.v.06 : change from one vehicle or transportation line to another
# in -> indium.n.01 : a rare soft silvery metallic element; occurs in small quantities in sphalerite
# ...
# it -> information_technology.n.01 : the branch of engineering that deals with the use of computers and telecommunications to retrieve and store and transmit information
# quickly -> quickly.r.01 : with rapid movements
#      Sentence 2: It is appropriate that the European Union means and that it should do so quickly.
# Tokens: ['it', 'is', 'appropriate', 'that', 'the', 'european', 'union', 'means', 'and', 'that', 'it', 'should', 'do', 'so', 'quickly']
# it -> information_technology.n.01 : the branch of engineering that deals with the use of computers and telecommunications to retrieve and store and transmit information
# is -> be.v.01 : have the quality of being; (copula, used with an adjective or a predicate noun)
# appropriate -> appropriate.v.02 : take possession of by force, as after an invasion
# european -> european.a.01 : of or relating to or characteristic of Europe or the people of Europe
# union -> union.s.01 : being of or having to do with the northern United States and those loyal to the Union during the American Civil War
# means -> mean.n.01 : an average of n numbers computed by adding some function of the numbers and dividing by some function of n
# it -> information_technology.n.01 : the branch of engineering that deals with the use of computers and telecommunications to retrieve and store and transmit information
# do -> practice.v.01 : carry out or practice; as of jobs and professions
# so -> thus.r.02 : in the way indicated; ; ; (`thusly' is a nonstandard variant)
# quickly -> quickly.r.01 : with rapid movements
# #################
#      Sentence 1: Unfortunately, others separate on the basis of accumulated hatred.
# Tokens: ['unfortunately', 'others', 'separate', 'on', 'the', 'basis', 'of', 'accumulated', 'hatred']
# unfortunately -> unfortunately.r.01 : by bad luck
# separate -> discriminate.v.02 : treat differently on the basis of sex or race
# on -> on.r.03 : in a state required for something to function or be effective
# basis -> basis.n.03 : the most important or necessary part of something
# accumulated -> accrued.s.01 : periodically accumulated over time
# hatred -> hate.n.01 : the emotion of intense dislike; a feeling of dislike so strong that it demands action
#      Sentence 2: Other separate unfortunately a accumulated resentment.
# Tokens: ['other', 'separate', 'unfortunately', 'a', 'accumulated', 'resentment']
# other -> other.s.04 : very unusual; different in character or quality from the normal or expected; - Lance Morrow
# separate -> separate.n.02 : a garment that can be purchased separately and worn in combinations with other garments
# unfortunately -> unfortunately.r.01 : by bad luck
# a -> deoxyadenosine_monophosphate.n.01 : one of the four nucleotides used in building DNA; all four nucleotides have a common phosphate group and a sugar (ribose)
# accumulated -> accrued.s.01 : periodically accumulated over time
# resentment -> resentment.n.01 : a feeling of deep and bitter anger and ill-will
# #################
#      Sentence 1: Then perhaps we could have avoided a catastrophe.
# Tokens: ['then', 'perhaps', 'we', 'could', 'have', 'avoided', 'a', 'catastrophe']
# then -> then.s.01 : at a specific prior time
# perhaps -> possibly.r.01 : by chance
# have -> have.v.07 : have a personal or business relationship with someone
# avoided -> keep_off.v.01 : refrain from certain foods or beverages
# a -> deoxyadenosine_monophosphate.n.01 : one of the four nucleotides used in building DNA; all four nucleotides have a common phosphate group and a sugar (ribose)
# catastrophe -> catastrophe.n.03 : a sudden violent change in the earth's surface
#      Sentence 2: We might have been able to prevent a disaster.
# Tokens: ['we', 'might', 'have', 'been', 'able', 'to', 'prevent', 'a', 'disaster']
# might -> might.n.01 : physical strength
# have -> induce.v.02 : cause to do; cause to act in a specified manner
# been -> be.v.01 : have the quality of being; (copula, used with an adjective or a predicate noun)
# able -> able.s.02 : have the skills and qualifications to do things well
# prevent -> prevent.v.02 : stop (someone or something) from doing something or being in a certain state
# a -> deoxyadenosine_monophosphate.n.01 : one of the four nucleotides used in building DNA; all four nucleotides have a common phosphate group and a sugar (ribose)
# disaster -> catastrophe.n.02 : a state of extreme (usually irremediable) ruin and misfortune
# #################
#      Sentence 1: Let me remind you that our allies include fervent supporters of this tax.
# Tokens: ['let', 'me', 'remind', 'you', 'that', 'our', 'allies', 'include', 'fervent', 'supporters', 'of', 'this', 'tax']
# let -> let.v.01 : make it possible through a specific action or lack of action for something to happen
# me -> maine.n.01 : a state in New England
# remind -> remind.v.01 : put in the mind of someone
# allies -> allies.n.02 : in World War I the alliance of Great Britain and France and Russia and all the other nations that became allied with them in opposing the Central Powers
# include -> include.v.03 : add as part of something else; put in as part of a set, group, or category
# fervent -> fervent.s.02 : extremely hot; - Nathaniel Hawthorne; - Frances Trollope
# supporters -> assistant.n.01 : a person who contributes to the fulfillment of a need or furtherance of an effort or purpose
# tax -> tax.v.02 : set or determine the amount of (a payment such as a fine)
#      Sentence 2: I would like to remind you that one of our allies, there are strong this tax.
# Tokens: ['i', 'would', 'like', 'to', 'remind', 'you', 'that', 'one', 'of', 'our', 'allies', 'there', 'are', 'strong', 'this', 'tax']
# i -> one.s.01 : used of a single unit or thing; not two or more
# like -> wish.v.02 : prefer or wish to do something
# remind -> remind.v.01 : put in the mind of someone
# one -> one.s.03 : of the same kind or quality
# allies -> allies.n.03 : an alliance of nations joining together to fight a common enemy
# there -> there.r.03 : to or toward that place; away from the speaker
# are -> are.n.01 : a unit of surface area equal to 100 square meters
# strong -> impregnable.s.01 : immune to attack; incapable of being tampered with
# tax -> tax.v.03 : use to the limit
# #################
#      Sentence 1: It is our job to continue to support Latvia with the integration of the Russian population.
# Tokens: ['it', 'is', 'our', 'job', 'to', 'continue', 'to', 'support', 'latvia', 'with', 'the', 'integration', 'of', 'the', 'russian', 'population']
# it -> information_technology.n.01 : the branch of engineering that deals with the use of computers and telecommunications to retrieve and store and transmit information
# is -> be.v.01 : have the quality of being; (copula, used with an adjective or a predicate noun)
# job -> problem.n.01 : a state of difficulty that needs to be resolved
# continue -> stay.v.04 : continue in a place, position, or situation
# support -> support.n.04 : a military operation (often involving new supplies of men and materiel) to strengthen a military force or aid in the performance of its mission
# latvia -> latvia.n.01 : a republic in northeastern Europe on the eastern coast of the Baltic Sea
# integration -> integration.n.03 : an operation used in the calculus whereby the integral of a function is determined
# russian -> russian.n.02 : the Slavic language that is the official language of Russia
# population -> population.n.05 : the act of populating (causing to live in a place)
#      Sentence 2: It is of our duty of continue to support the country on the issue of the integration of the Russian people.
# Tokens: ['it', 'is', 'of', 'our', 'duty', 'of', 'continue', 'to', 'support', 'the', 'country', 'on', 'the', 'issue', 'of', 'the', 'integration', 'of', 'the', 'russian', 'people']
# it -> information_technology.n.01 : the branch of engineering that deals with the use of computers and telecommunications to retrieve and store and transmit information
# is -> embody.v.02 : represent, as of a character on stage
# duty -> duty.n.01 : the social force that binds you to the courses of action demanded by that force; ; - John D.Rockefeller Jr
# continue -> stay.v.04 : continue in a place, position, or situation
# support -> support.n.04 : a military operation (often involving new supplies of men and materiel) to strengthen a military force or aid in the performance of its mission
# country -> nation.n.02 : the people who live in a nation or country
# on -> on.r.03 : in a state required for something to function or be effective
# issue -> return.n.06 : the income or profit arising from such transactions as the sale of land or other property
# integration -> integration.n.03 : an operation used in the calculus whereby the integral of a function is determined
# russian -> russian.n.02 : the Slavic language that is the official language of Russia
# people -> citizenry.n.01 : the body of citizens of a state or country
# #################
#      Sentence 1: The vote will take place today at 5.30 p.m.
# Tokens: ['the', 'vote', 'will', 'take', 'place', 'today', 'at']
# vote -> vote.v.05 : bring into existence or make available by vote
# will -> will.n.03 : a legal document declaring a person's wishes regarding the disposal of their property when they die
# take -> take.v.24 : ascertain or determine by measuring, computing or take a reading from a dial
# place -> place.v.12 : identify the location or place of
# today -> today.n.02 : the day that includes the present moment (as opposed to yesterday or tomorrow)
# at -> at.n.02 : 100 at equal 1 kip in Laos
#      Sentence 2: Vote will take place at 17 h 30.
# Tokens: ['vote', 'will', 'take', 'place', 'at', 'h']
# vote -> vote.v.05 : bring into existence or make available by vote
# will -> bequeath.v.01 : leave or give by will after one's death
# take -> take.v.24 : ascertain or determine by measuring, computing or take a reading from a dial
# place -> place.v.06 : take a place in a competition; often followed by an ordinal
# at -> at.n.02 : 100 at equal 1 kip in Laos
# h -> henry.n.01 : a unit of inductance in which an induced electromotive force of one volt is produced when the current is varied at the rate of one ampere per second
# #################
#      Sentence 1: Neither was there a qualified majority within this House to revert to Article 272.
# Tokens: ['neither', 'was', 'there', 'a', 'qualified', 'majority', 'within', 'this', 'house', 'to', 'revert', 'to', 'article']
# neither -> neither.s.01 : not either; not one or the other
# was -> washington.n.02 : a state in northwestern United States on the Pacific
# there -> there.r.03 : to or toward that place; away from the speaker
# a -> angstrom.n.01 : a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation
# qualified -> certified.s.03 : holding appropriate documentation and officially on record as qualified to perform a specified function or practice a specified skill
# majority -> majority.n.03 : the age at which persons are considered competent to manage their own affairs
# within -> inside.r.02 : on the inside
# house -> house.n.09 : the management of a gambling house or casino
# revert -> revert.v.01 : go back to a previous state
# article -> article.v.01 : bind by a contract; especially for a training period
#      Sentence 2: There was no qualified majority in this Parliament to go back to Article 272.
# Tokens: ['there', 'was', 'no', 'qualified', 'majority', 'in', 'this', 'parliament', 'to', 'go', 'back', 'to', 'article']
# there -> there.r.03 : to or toward that place; away from the speaker
# was -> be.v.12 : to remain unmolested, undisturbed, or uninterrupted -- used only in infinitive form
# no -> no.r.03 : used to express refusal or denial or disagreement etc or especially to emphasize a negative statement
# qualified -> certified.s.03 : holding appropriate documentation and officially on record as qualified to perform a specified function or practice a specified skill
# majority -> majority.n.01 : the property resulting from being or relating to the greater in number of two parts; the main part
# in -> indium.n.01 : a rare soft silvery metallic element; occurs in small quantities in sphalerite
# parliament -> fantan.n.02 : a card game in which you play your sevens and other cards in sequence in the same suit as the sevens; you win if you are the first to use all your cards
# go -> rifle.v.02 : go through in search of something; search through someone's belongings in an unauthorized way
# back -> back.v.06 : be in back of
# article -> article.v.01 : bind by a contract; especially for a training period
# #################
#      Sentence 1: Let me remind you that our allies include fervent supporters of this tax.
# Tokens: ['let', 'me', 'remind', 'you', 'that', 'our', 'allies', 'include', 'fervent', 'supporters', 'of', 'this', 'tax']
# let -> let.v.01 : make it possible through a specific action or lack of action for something to happen
# me -> maine.n.01 : a state in New England
# remind -> remind.v.01 : put in the mind of someone
# allies -> allies.n.02 : in World War I the alliance of Great Britain and France and Russia and all the other nations that became allied with them in opposing the Central Powers
# include -> include.v.03 : add as part of something else; put in as part of a set, group, or category
# fervent -> fervent.s.02 : extremely hot; - Nathaniel Hawthorne; - Frances Trollope
# supporters -> assistant.n.01 : a person who contributes to the fulfillment of a need or furtherance of an effort or purpose
# tax -> tax.v.02 : set or determine the amount of (a payment such as a fine)
#      Sentence 2: I hold you recall that our allies, there are enthusiastic about this tax.
# Tokens: ['i', 'hold', 'you', 'recall', 'that', 'our', 'allies', 'there', 'are', 'enthusiastic', 'about', 'this', 'tax']
# i -> one.n.01 : the smallest whole number or a numeral representing this number
# hold -> restrain.v.03 : to close within bounds, limit or hold back from movement
# recall -> remember.v.01 : recall knowledge from memory; have a recollection
# allies -> allies.n.02 : in World War I the alliance of Great Britain and France and Russia and all the other nations that became allied with them in opposing the Central Powers
# there -> there.r.03 : to or toward that place; away from the speaker
# are -> exist.v.01 : have an existence, be extant
# enthusiastic -> enthusiastic.a.01 : having or showing great excitement and interest
# about -> approximately.r.01 : (of quantities) imprecise but fairly close to correct
# tax -> tax.v.01 : levy a tax on
# #################
#      Sentence 1: We often pontificate here about being the representatives of the citizens of Europe.
# Tokens: ['we', 'often', 'pontificate', 'here', 'about', 'being', 'the', 'representatives', 'of', 'the', 'citizens', 'of', 'europe']
# often -> often.r.03 : in many cases or instances
# pontificate -> papacy.n.01 : the government of the Roman Catholic Church
# here -> here.s.01 : being here now
# about -> about.s.01 : on the move
# being -> being.n.01 : the state or fact of existing
# representatives -> congressman.n.01 : a member of the United States House of Representatives
# citizens -> citizen.n.01 : a native or naturalized member of a state or other political community
# europe -> europe.n.03 : the nations of the European continent collectively
#      Sentence 2: We often take pride here to represent the citizens of Europe.
# Tokens: ['we', 'often', 'take', 'pride', 'here', 'to', 'represent', 'the', 'citizens', 'of', 'europe']
# often -> often.r.03 : in many cases or instances
# take -> take.v.34 : to get into a position of having, e.g., safety, comfort
# pride -> pride.n.05 : unreasonable and inordinate self-esteem (personified as one of the deadly sins)
# here -> here.r.03 : to this place (especially toward the speaker)
# represent -> represent.v.01 : take the place of or be parallel or equivalent to
# citizens -> citizen.n.01 : a native or naturalized member of a state or other political community
# europe -> europe.n.01 : the 2nd smallest continent (actually a vast peninsula of Eurasia); the British use `Europe' to refer to all of the continent except the British Isles
